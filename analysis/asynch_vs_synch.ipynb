# %%
import pandas as pd

# %% [markdown]
# ## Base

# %% [markdown]
# ### 64

# %%
# Ethernet
ddp_2_b_64_eth1 = pd.read_csv("../log/synch_ddp/rank_0_synch_ddp_2_minibatch_64_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_4_b_64_eth1 = pd.read_csv("../log/synch_ddp/rank_0_synch_ddp_4_minibatch_64_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_8_b_64_eth1 = pd.read_csv("../log/synch_ddp/rank_0_synch_ddp_8_minibatch_64_vit-base-patch16-224-in21k_model_eth1.csv")

ddp_2_b_64_eth1 = ddp_2_b_64_eth1[ddp_2_b_64_eth1['phase'] == 'train']
ddp_4_b_64_eth1 = ddp_4_b_64_eth1[ddp_4_b_64_eth1['phase'] == 'train']
ddp_8_b_64_eth1 = ddp_8_b_64_eth1[ddp_8_b_64_eth1['phase'] == 'train']


ddp_2_b_64_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_64_tau_2_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_4_b_64_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_64_tau_2_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_8_b_64_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_64_tau_2_vit-base-patch16-224-in21k_model_eth1.csv")

ddp_2_b_64_2_eth1 = ddp_2_b_64_2_eth1[ddp_2_b_64_2_eth1['phase'] == 'train']
ddp_4_b_64_2_eth1 = ddp_4_b_64_2_eth1[ddp_4_b_64_2_eth1['phase'] == 'train']
ddp_8_b_64_2_eth1 = ddp_8_b_64_2_eth1[ddp_8_b_64_2_eth1['phase'] == 'train']

ddp_2_b_64_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_64_tau_4_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_4_b_64_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_64_tau_4_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_8_b_64_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_64_tau_4_vit-base-patch16-224-in21k_model_eth1.csv")

ddp_2_b_64_4_eth1 = ddp_2_b_64_4_eth1[ddp_2_b_64_4_eth1['phase'] == 'train']
ddp_4_b_64_4_eth1 = ddp_4_b_64_4_eth1[ddp_4_b_64_4_eth1['phase'] == 'train']
ddp_8_b_64_4_eth1 = ddp_8_b_64_4_eth1[ddp_8_b_64_4_eth1['phase'] == 'train']

ddp_2_b_64_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_64_tau_8_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_4_b_64_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_64_tau_8_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_8_b_64_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_64_tau_8_vit-base-patch16-224-in21k_model_eth1.csv")

ddp_2_b_64_8_eth1 = ddp_2_b_64_8_eth1[ddp_2_b_64_8_eth1['phase'] == 'train']
ddp_4_b_64_8_eth1 = ddp_4_b_64_8_eth1[ddp_4_b_64_8_eth1['phase'] == 'train']
ddp_8_b_64_8_eth1 = ddp_8_b_64_8_eth1[ddp_8_b_64_8_eth1['phase'] == 'train']


# sum the columns forward_time and backward_time and then sum the total minibatch_time
ddp_2_b_64_eth1['total_time'] = ddp_2_b_64_eth1['forward_time'] + ddp_2_b_64_eth1['backward_time']
ddp_4_b_64_eth1['total_time'] = ddp_4_b_64_eth1['forward_time'] + ddp_4_b_64_eth1['backward_time']
ddp_8_b_64_eth1['total_time'] = ddp_8_b_64_eth1['forward_time'] + ddp_8_b_64_eth1['backward_time']
ddp_2_b_64_2_eth1['total_time'] = ddp_2_b_64_2_eth1['forward_time'] + ddp_2_b_64_2_eth1['backward_time'] + ddp_2_b_64_2_eth1['synch_avg_time']
ddp_4_b_64_2_eth1['total_time'] = ddp_4_b_64_2_eth1['forward_time'] + ddp_4_b_64_2_eth1['backward_time'] + ddp_4_b_64_2_eth1['synch_avg_time']
ddp_8_b_64_2_eth1['total_time'] = ddp_8_b_64_2_eth1['forward_time'] + ddp_8_b_64_2_eth1['backward_time'] + ddp_8_b_64_2_eth1['synch_avg_time']
ddp_2_b_64_4_eth1['total_time'] = ddp_2_b_64_4_eth1['forward_time'] + ddp_2_b_64_4_eth1['backward_time'] + ddp_2_b_64_4_eth1['synch_avg_time']
ddp_4_b_64_4_eth1['total_time'] = ddp_4_b_64_4_eth1['forward_time'] + ddp_4_b_64_4_eth1['backward_time'] + ddp_4_b_64_4_eth1['synch_avg_time']
ddp_8_b_64_4_eth1['total_time'] = ddp_8_b_64_4_eth1['forward_time'] + ddp_8_b_64_4_eth1['backward_time'] + ddp_8_b_64_4_eth1['synch_avg_time']
ddp_2_b_64_8_eth1['total_time'] = ddp_2_b_64_8_eth1['forward_time'] + ddp_2_b_64_8_eth1['backward_time'] + ddp_2_b_64_8_eth1['synch_avg_time']
ddp_4_b_64_8_eth1['total_time'] = ddp_4_b_64_8_eth1['forward_time'] + ddp_4_b_64_8_eth1['backward_time'] + ddp_4_b_64_8_eth1['synch_avg_time']
ddp_8_b_64_8_eth1['total_time'] = ddp_8_b_64_8_eth1['forward_time'] + ddp_8_b_64_8_eth1['backward_time'] + ddp_8_b_64_8_eth1['synch_avg_time']

# compuite the speedup of asynchronous DDP over synchronous DDP
ddp_2_b_64_2_eth1['speedup'] = ddp_2_b_64_eth1['total_time'] / ddp_2_b_64_2_eth1['total_time']
ddp_4_b_64_2_eth1['speedup'] = ddp_4_b_64_eth1['total_time'] / ddp_4_b_64_2_eth1['total_time']
ddp_8_b_64_2_eth1['speedup'] = ddp_8_b_64_eth1['total_time'] / ddp_8_b_64_2_eth1['total_time']

ddp_2_b_64_4_eth1['speedup'] = ddp_2_b_64_eth1['total_time'] / ddp_2_b_64_4_eth1['total_time']
ddp_4_b_64_4_eth1['speedup'] = ddp_4_b_64_eth1['total_time'] / ddp_4_b_64_4_eth1['total_time']
ddp_8_b_64_4_eth1['speedup'] = ddp_8_b_64_eth1['total_time'] / ddp_8_b_64_4_eth1['total_time']

ddp_2_b_64_8_eth1['speedup'] = ddp_2_b_64_eth1['total_time'] / ddp_2_b_64_8_eth1['total_time']
ddp_4_b_64_8_eth1['speedup'] = ddp_4_b_64_eth1['total_time'] / ddp_4_b_64_8_eth1['total_time']
ddp_8_b_64_8_eth1['speedup'] = ddp_8_b_64_eth1['total_time'] / ddp_8_b_64_8_eth1['total_time']

# print the speedup
print("Speedup for 2 Workers with tau=2:", ddp_2_b_64_2_eth1['speedup'].mean())
print("Speedup for 4 Workers with tau=2:", ddp_4_b_64_2_eth1['speedup'].mean())
print("Speedup for 8 Workers with tau=2:", ddp_8_b_64_2_eth1['speedup'].mean())

print("Speedup for 2 Workers with tau=4:", ddp_2_b_64_4_eth1['speedup'].mean())
print("Speedup for 4 Workers with tau=4:", ddp_4_b_64_4_eth1['speedup'].mean())
print("Speedup for 8 Workers with tau=4:", ddp_8_b_64_4_eth1['speedup'].mean())

print("Speedup for 2 Workers with tau=8:", ddp_2_b_64_8_eth1['speedup'].mean())
print("Speedup for 4 Workers with tau=8:", ddp_4_b_64_8_eth1['speedup'].mean())
print("Speedup for 8 Workers with tau=8:", ddp_8_b_64_8_eth1['speedup'].mean())
# Out:
# Speedup for 2 Workers with tau=2: 1.0718887534708834
# Speedup for 4 Workers with tau=2: 1.2233911168155396
# Speedup for 8 Workers with tau=2: 1.5040792340972318
# Speedup for 2 Workers with tau=4: 1.0906009252998183
# Speedup for 4 Workers with tau=4: 1.3403949773967287
# Speedup for 8 Workers with tau=4: 1.6993513006223342
# Speedup for 2 Workers with tau=8: 1.1098944150362848
# Speedup for 4 Workers with tau=8: 1.3740935015476448
# Speedup for 8 Workers with tau=8: 1.8070464309097534

# %%
# OPX 
ddp_2_b_64_ib0 = pd.read_csv("../log/synch_ddp/rank_0_synch_ddp_2_minibatch_64_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_4_b_64_ib0 = pd.read_csv("../log/synch_ddp/rank_0_synch_ddp_4_minibatch_64_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_8_b_64_ib0 = pd.read_csv("../log/synch_ddp/rank_0_synch_ddp_8_minibatch_64_vit-base-patch16-224-in21k_model_ib0.csv")

ddp_2_b_64_ib0 = ddp_2_b_64_ib0[ddp_2_b_64_ib0['phase'] == 'train']
ddp_4_b_64_ib0 = ddp_4_b_64_ib0[ddp_4_b_64_ib0['phase'] == 'train']
ddp_8_b_64_ib0 = ddp_8_b_64_ib0[ddp_8_b_64_ib0['phase'] == 'train']

ddp_2_b_64_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_64_tau_2_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_4_b_64_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_64_tau_2_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_8_b_64_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_64_tau_2_vit-base-patch16-224-in21k_model_ib0.csv")

ddp_2_b_64_2_ib0 = ddp_2_b_64_2_ib0[ddp_2_b_64_2_ib0['phase'] == 'train']
ddp_4_b_64_2_ib0 = ddp_4_b_64_2_ib0[ddp_4_b_64_2_ib0['phase'] == 'train']
ddp_8_b_64_2_ib0 = ddp_8_b_64_2_ib0[ddp_8_b_64_2_ib0['phase'] == 'train']

ddp_2_b_64_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_64_tau_4_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_4_b_64_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_64_tau_4_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_8_b_64_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_64_tau_4_vit-base-patch16-224-in21k_model_ib0.csv")

ddp_2_b_64_4_ib0 = ddp_2_b_64_4_ib0[ddp_2_b_64_4_ib0['phase'] == 'train']
ddp_4_b_64_4_ib0 = ddp_4_b_64_4_ib0[ddp_4_b_64_4_ib0['phase'] == 'train']
ddp_8_b_64_4_ib0 = ddp_8_b_64_4_ib0[ddp_8_b_64_4_ib0['phase'] == 'train']

ddp_2_b_64_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_64_tau_8_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_4_b_64_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_64_tau_8_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_8_b_64_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_64_tau_8_vit-base-patch16-224-in21k_model_ib0.csv")

ddp_2_b_64_8_ib0 = ddp_2_b_64_8_ib0[ddp_2_b_64_8_ib0['phase'] == 'train']
ddp_4_b_64_8_ib0 = ddp_4_b_64_8_ib0[ddp_4_b_64_8_ib0['phase'] == 'train']
ddp_8_b_64_8_ib0 = ddp_8_b_64_8_ib0[ddp_8_b_64_8_ib0['phase'] == 'train']

ddp_2_b_64_ib0['total_time'] = ddp_2_b_64_ib0['forward_time'] + ddp_2_b_64_ib0['backward_time']
ddp_4_b_64_ib0['total_time'] = ddp_4_b_64_ib0['forward_time'] + ddp_4_b_64_ib0['backward_time']
ddp_8_b_64_ib0['total_time'] = ddp_8_b_64_ib0['forward_time'] + ddp_8_b_64_ib0['backward_time']
ddp_2_b_64_2_ib0['total_time'] = ddp_2_b_64_2_ib0['forward_time'] + ddp_2_b_64_2_ib0['backward_time'] + ddp_2_b_64_2_ib0['synch_avg_time']
ddp_4_b_64_2_ib0['total_time'] = ddp_4_b_64_2_ib0['forward_time'] + ddp_4_b_64_2_ib0['backward_time'] + ddp_4_b_64_2_ib0['synch_avg_time']
ddp_8_b_64_2_ib0['total_time'] = ddp_8_b_64_2_ib0['forward_time'] + ddp_8_b_64_2_ib0['backward_time'] + ddp_8_b_64_2_ib0['synch_avg_time']
ddp_2_b_64_4_ib0['total_time'] = ddp_2_b_64_4_ib0['forward_time'] + ddp_2_b_64_4_ib0['backward_time'] + ddp_2_b_64_4_ib0['synch_avg_time']
ddp_4_b_64_4_ib0['total_time'] = ddp_4_b_64_4_ib0['forward_time'] + ddp_4_b_64_4_ib0['backward_time'] + ddp_4_b_64_4_ib0['synch_avg_time']
ddp_8_b_64_4_ib0['total_time'] = ddp_8_b_64_4_ib0['forward_time'] + ddp_8_b_64_4_ib0['backward_time'] + ddp_8_b_64_4_ib0['synch_avg_time']
ddp_2_b_64_8_ib0['total_time'] = ddp_2_b_64_8_ib0['forward_time'] + ddp_2_b_64_8_ib0['backward_time'] + ddp_2_b_64_8_ib0['synch_avg_time']
ddp_4_b_64_8_ib0['total_time'] = ddp_4_b_64_8_ib0['forward_time'] + ddp_4_b_64_8_ib0['backward_time'] + ddp_4_b_64_8_ib0['synch_avg_time']
ddp_8_b_64_8_ib0['total_time'] = ddp_8_b_64_8_ib0['forward_time'] + ddp_8_b_64_8_ib0['backward_time'] + ddp_8_b_64_8_ib0['synch_avg_time']

ddp_2_b_64_2_ib0['speedup'] = ddp_2_b_64_ib0['total_time'] / ddp_2_b_64_2_ib0['total_time']
ddp_4_b_64_2_ib0['speedup'] = ddp_4_b_64_ib0['total_time'] / ddp_4_b_64_2_ib0['total_time']
ddp_8_b_64_2_ib0['speedup'] = ddp_8_b_64_ib0['total_time'] / ddp_8_b_64_2_ib0['total_time']

ddp_2_b_64_4_ib0['speedup'] = ddp_2_b_64_ib0['total_time'] / ddp_2_b_64_4_ib0['total_time']
ddp_4_b_64_4_ib0['speedup'] = ddp_4_b_64_ib0['total_time'] / ddp_4_b_64_4_ib0['total_time']
ddp_8_b_64_4_ib0['speedup'] = ddp_8_b_64_ib0['total_time'] / ddp_8_b_64_4_ib0['total_time']

ddp_2_b_64_8_ib0['speedup'] = ddp_2_b_64_ib0['total_time'] / ddp_2_b_64_8_ib0['total_time']
ddp_4_b_64_8_ib0['speedup'] = ddp_4_b_64_ib0['total_time'] / ddp_4_b_64_8_ib0['total_time']
ddp_8_b_64_8_ib0['speedup'] = ddp_8_b_64_ib0['total_time'] / ddp_8_b_64_8_ib0['total_time']

print("Speedup for 2 Workers with tau=2:", ddp_2_b_64_2_ib0['speedup'].mean())
print("Speedup for 4 Workers with tau=2:", ddp_4_b_64_2_ib0['speedup'].mean())
print("Speedup for 8 Workers with tau=2:", ddp_8_b_64_2_ib0['speedup'].mean())

print("Speedup for 2 Workers with tau=4:", ddp_2_b_64_4_ib0['speedup'].mean())
print("Speedup for 4 Workers with tau=4:", ddp_4_b_64_4_ib0['speedup'].mean())
print("Speedup for 8 Workers with tau=4:", ddp_8_b_64_4_ib0['speedup'].mean())

print("Speedup for 2 Workers with tau=8:", ddp_2_b_64_8_ib0['speedup'].mean())
print("Speedup for 4 Workers with tau=8:", ddp_4_b_64_8_ib0['speedup'].mean())
print("Speedup for 8 Workers with tau=8:", ddp_8_b_64_8_ib0['speedup'].mean())
# Out:
# Speedup for 2 Workers with tau=2: 1.037674548158341
# Speedup for 4 Workers with tau=2: 1.2095413295953559
# Speedup for 8 Workers with tau=2: 1.4554144019438842
# Speedup for 2 Workers with tau=4: 1.042207913292338
# Speedup for 4 Workers with tau=4: 1.2435584762295278
# Speedup for 8 Workers with tau=4: 1.5224829665854978
# Speedup for 2 Workers with tau=8: 1.0575041941960033
# Speedup for 4 Workers with tau=8: 1.2669292822678693
# Speedup for 8 Workers with tau=8: 1.5728948411493473

# %% [markdown]
# ### 128

# %%
# Ethernet - 128
ddp_2_b_128_eth1 = pd.read_csv("../log/synch_ddp/rank_0_synch_ddp_2_minibatch_128_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_4_b_128_eth1 = pd.read_csv("../log/synch_ddp/rank_0_synch_ddp_4_minibatch_128_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_8_b_128_eth1 = pd.read_csv("../log/synch_ddp/rank_0_synch_ddp_8_minibatch_128_vit-base-patch16-224-in21k_model_eth1.csv")

ddp_2_b_128_eth1 = ddp_2_b_128_eth1[ddp_2_b_128_eth1['phase'] == 'train']
ddp_4_b_128_eth1 = ddp_4_b_128_eth1[ddp_4_b_128_eth1['phase'] == 'train']
ddp_8_b_128_eth1 = ddp_8_b_128_eth1[ddp_8_b_128_eth1['phase'] == 'train']

ddp_2_b_128_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_128_tau_2_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_4_b_128_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_128_tau_2_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_8_b_128_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_128_tau_2_vit-base-patch16-224-in21k_model_eth1.csv")

ddp_2_b_128_2_eth1 = ddp_2_b_128_2_eth1[ddp_2_b_128_2_eth1['phase'] == 'train']
ddp_4_b_128_2_eth1 = ddp_4_b_128_2_eth1[ddp_4_b_128_2_eth1['phase'] == 'train']
ddp_8_b_128_2_eth1 = ddp_8_b_128_2_eth1[ddp_8_b_128_2_eth1['phase'] == 'train']

ddp_2_b_128_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_128_tau_4_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_4_b_128_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_128_tau_4_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_8_b_128_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_128_tau_4_vit-base-patch16-224-in21k_model_eth1.csv")

ddp_2_b_128_4_eth1 = ddp_2_b_128_4_eth1[ddp_2_b_128_4_eth1['phase'] == 'train']
ddp_4_b_128_4_eth1 = ddp_4_b_128_4_eth1[ddp_4_b_128_4_eth1['phase'] == 'train']
ddp_8_b_128_4_eth1 = ddp_8_b_128_4_eth1[ddp_8_b_128_4_eth1['phase'] == 'train']

ddp_2_b_128_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_128_tau_8_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_4_b_128_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_128_tau_8_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_8_b_128_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_128_tau_8_vit-base-patch16-224-in21k_model_eth1.csv")

ddp_2_b_128_8_eth1 = ddp_2_b_128_8_eth1[ddp_2_b_128_8_eth1['phase'] == 'train']
ddp_4_b_128_8_eth1 = ddp_4_b_128_8_eth1[ddp_4_b_128_8_eth1['phase'] == 'train']
ddp_8_b_128_8_eth1 = ddp_8_b_128_8_eth1[ddp_8_b_128_8_eth1['phase'] == 'train']

ddp_2_b_128_eth1['total_time'] = ddp_2_b_128_eth1['forward_time'] + ddp_2_b_128_eth1['backward_time']
ddp_4_b_128_eth1['total_time'] = ddp_4_b_128_eth1['forward_time'] + ddp_4_b_128_eth1['backward_time']
ddp_8_b_128_eth1['total_time'] = ddp_8_b_128_eth1['forward_time'] + ddp_8_b_128_eth1['backward_time']
ddp_2_b_128_2_eth1['total_time'] = ddp_2_b_128_2_eth1['forward_time'] + ddp_2_b_128_2_eth1['backward_time'] + ddp_2_b_128_2_eth1['synch_avg_time']
ddp_4_b_128_2_eth1['total_time'] = ddp_4_b_128_2_eth1['forward_time'] + ddp_4_b_128_2_eth1['backward_time'] + ddp_4_b_128_2_eth1['synch_avg_time']
ddp_8_b_128_2_eth1['total_time'] = ddp_8_b_128_2_eth1['forward_time'] + ddp_8_b_128_2_eth1['backward_time'] + ddp_8_b_128_2_eth1['synch_avg_time']
ddp_2_b_128_4_eth1['total_time'] = ddp_2_b_128_4_eth1['forward_time'] + ddp_2_b_128_4_eth1['backward_time'] + ddp_2_b_128_4_eth1['synch_avg_time']
ddp_4_b_128_4_eth1['total_time'] = ddp_4_b_128_4_eth1['forward_time'] + ddp_4_b_128_4_eth1['backward_time'] + ddp_4_b_128_4_eth1['synch_avg_time']
ddp_8_b_128_4_eth1['total_time'] = ddp_8_b_128_4_eth1['forward_time'] + ddp_8_b_128_4_eth1['backward_time'] + ddp_8_b_128_4_eth1['synch_avg_time']
ddp_2_b_128_8_eth1['total_time'] = ddp_2_b_128_8_eth1['forward_time'] + ddp_2_b_128_8_eth1['backward_time'] + ddp_2_b_128_8_eth1['synch_avg_time']
ddp_4_b_128_8_eth1['total_time'] = ddp_4_b_128_8_eth1['forward_time'] + ddp_4_b_128_8_eth1['backward_time'] + ddp_4_b_128_8_eth1['synch_avg_time']
ddp_8_b_128_8_eth1['total_time'] = ddp_8_b_128_8_eth1['forward_time'] + ddp_8_b_128_8_eth1['backward_time'] + ddp_8_b_128_8_eth1['synch_avg_time']

ddp_2_b_128_2_eth1['speedup'] = ddp_2_b_128_eth1['total_time'] / ddp_2_b_128_2_eth1['total_time']
ddp_4_b_128_2_eth1['speedup'] = ddp_4_b_128_eth1['total_time'] / ddp_4_b_128_2_eth1['total_time']
ddp_8_b_128_2_eth1['speedup'] = ddp_8_b_128_eth1['total_time'] / ddp_8_b_128_2_eth1['total_time']

ddp_2_b_128_4_eth1['speedup'] = ddp_2_b_128_eth1['total_time'] / ddp_2_b_128_4_eth1['total_time']
ddp_4_b_128_4_eth1['speedup'] = ddp_4_b_128_eth1['total_time'] / ddp_4_b_128_4_eth1['total_time']
ddp_8_b_128_4_eth1['speedup'] = ddp_8_b_128_eth1['total_time'] / ddp_8_b_128_4_eth1['total_time']

ddp_2_b_128_8_eth1['speedup'] = ddp_2_b_128_eth1['total_time'] / ddp_2_b_128_8_eth1['total_time']
ddp_4_b_128_8_eth1['speedup'] = ddp_4_b_128_eth1['total_time'] / ddp_4_b_128_8_eth1['total_time']
ddp_8_b_128_8_eth1['speedup'] = ddp_8_b_128_eth1['total_time'] / ddp_8_b_128_8_eth1['total_time']

print("Speedup for 2 Workers with tau=2:", ddp_2_b_128_2_eth1['speedup'].mean())
print("Speedup for 4 Workers with tau=2:", ddp_4_b_128_2_eth1['speedup'].mean())
print("Speedup for 8 Workers with tau=2:", ddp_8_b_128_2_eth1['speedup'].mean())

print("Speedup for 2 Workers with tau=4:", ddp_2_b_128_4_eth1['speedup'].mean())
print("Speedup for 4 Workers with tau=4:", ddp_4_b_128_4_eth1['speedup'].mean())
print("Speedup for 8 Workers with tau=4:", ddp_8_b_128_4_eth1['speedup'].mean())

print("Speedup for 2 Workers with tau=8:", ddp_2_b_128_8_eth1['speedup'].mean())
print("Speedup for 4 Workers with tau=8:", ddp_4_b_128_8_eth1['speedup'].mean())
print("Speedup for 8 Workers with tau=8:", ddp_8_b_128_8_eth1['speedup'].mean())
# Out:
# Speedup for 2 Workers with tau=2: 1.0316278706328688
# Speedup for 4 Workers with tau=2: 1.1310622282291884
# Speedup for 8 Workers with tau=2: 1.2644991473679932
# Speedup for 2 Workers with tau=4: 1.044756341475988
# Speedup for 4 Workers with tau=4: 1.1742061082381303
# Speedup for 8 Workers with tau=4: 1.3579400532738146
# Speedup for 2 Workers with tau=8: 1.0562213337945716
# Speedup for 4 Workers with tau=8: 1.205963651847409
# Speedup for 8 Workers with tau=8: 1.424133838938675

# %%
# OPX - 128
ddp_2_b_128_ib0 = pd.read_csv("../log/synch_ddp/rank_0_synch_ddp_2_minibatch_128_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_4_b_128_ib0 = pd.read_csv("../log/synch_ddp/rank_0_synch_ddp_4_minibatch_128_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_8_b_128_ib0 = pd.read_csv("../log/synch_ddp/rank_0_synch_ddp_8_minibatch_128_vit-base-patch16-224-in21k_model_ib0.csv")

ddp_2_b_128_ib0 = ddp_2_b_128_ib0[ddp_2_b_128_ib0['phase'] == 'train']
ddp_4_b_128_ib0 = ddp_4_b_128_ib0[ddp_4_b_128_ib0['phase'] == 'train']
ddp_8_b_128_ib0 = ddp_8_b_128_ib0[ddp_8_b_128_ib0['phase'] == 'train']

ddp_2_b_128_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_128_tau_2_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_4_b_128_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_128_tau_2_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_8_b_128_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_128_tau_2_vit-base-patch16-224-in21k_model_ib0.csv")

ddp_2_b_128_2_ib0 = ddp_2_b_128_2_ib0[ddp_2_b_128_2_ib0['phase'] == 'train']
ddp_4_b_128_2_ib0 = ddp_4_b_128_2_ib0[ddp_4_b_128_2_ib0['phase'] == 'train']
ddp_8_b_128_2_ib0 = ddp_8_b_128_2_ib0[ddp_8_b_128_2_ib0['phase'] == 'train']

ddp_2_b_128_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_128_tau_4_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_4_b_128_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_128_tau_4_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_8_b_128_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_128_tau_4_vit-base-patch16-224-in21k_model_ib0.csv")

ddp_2_b_128_4_ib0 = ddp_2_b_128_4_ib0[ddp_2_b_128_4_ib0['phase'] == 'train']
ddp_4_b_128_4_ib0 = ddp_4_b_128_4_ib0[ddp_4_b_128_4_ib0['phase'] == 'train']
ddp_8_b_128_4_ib0 = ddp_8_b_128_4_ib0[ddp_8_b_128_4_ib0['phase'] == 'train']

ddp_2_b_128_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_128_tau_8_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_4_b_128_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_128_tau_8_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_8_b_128_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_128_tau_8_vit-base-patch16-224-in21k_model_ib0.csv")

ddp_2_b_128_8_ib0 = ddp_2_b_128_8_ib0[ddp_2_b_128_8_ib0['phase'] == 'train']
ddp_4_b_128_8_ib0 = ddp_4_b_128_8_ib0[ddp_4_b_128_8_ib0['phase'] == 'train']
ddp_8_b_128_8_ib0 = ddp_8_b_128_8_ib0[ddp_8_b_128_8_ib0['phase'] == 'train']

ddp_2_b_128_ib0['total_time'] = ddp_2_b_128_ib0['forward_time'] + ddp_2_b_128_ib0['backward_time']
ddp_4_b_128_ib0['total_time'] = ddp_4_b_128_ib0['forward_time'] + ddp_4_b_128_ib0['backward_time']
ddp_8_b_128_ib0['total_time'] = ddp_8_b_128_ib0['forward_time'] + ddp_8_b_128_ib0['backward_time']
ddp_2_b_128_2_ib0['total_time'] = ddp_2_b_128_2_ib0['forward_time'] + ddp_2_b_128_2_ib0['backward_time'] + ddp_2_b_128_2_ib0['synch_avg_time']
ddp_4_b_128_2_ib0['total_time'] = ddp_4_b_128_2_ib0['forward_time'] + ddp_4_b_128_2_ib0['backward_time'] + ddp_4_b_128_2_ib0['synch_avg_time']
ddp_8_b_128_2_ib0['total_time'] = ddp_8_b_128_2_ib0['forward_time'] + ddp_8_b_128_2_ib0['backward_time'] + ddp_8_b_128_2_ib0['synch_avg_time']
ddp_2_b_128_4_ib0['total_time'] = ddp_2_b_128_4_ib0['forward_time'] + ddp_2_b_128_4_ib0['backward_time'] + ddp_2_b_128_4_ib0['synch_avg_time']
ddp_4_b_128_4_ib0['total_time'] = ddp_4_b_128_4_ib0['forward_time'] + ddp_4_b_128_4_ib0['backward_time'] + ddp_4_b_128_4_ib0['synch_avg_time']
ddp_8_b_128_4_ib0['total_time'] = ddp_8_b_128_4_ib0['forward_time'] + ddp_8_b_128_4_ib0['backward_time'] + ddp_8_b_128_4_ib0['synch_avg_time']
ddp_2_b_128_8_ib0['total_time'] = ddp_2_b_128_8_ib0['forward_time'] + ddp_2_b_128_8_ib0['backward_time'] + ddp_2_b_128_8_ib0['synch_avg_time']
ddp_4_b_128_8_ib0['total_time'] = ddp_4_b_128_8_ib0['forward_time'] + ddp_4_b_128_8_ib0['backward_time'] + ddp_4_b_128_8_ib0['synch_avg_time']
ddp_8_b_128_8_ib0['total_time'] = ddp_8_b_128_8_ib0['forward_time'] + ddp_8_b_128_8_ib0['backward_time'] + ddp_8_b_128_8_ib0['synch_avg_time']

ddp_2_b_128_2_ib0['speedup'] = ddp_2_b_128_ib0['total_time'] / ddp_2_b_128_2_ib0['total_time']
ddp_4_b_128_2_ib0['speedup'] = ddp_4_b_128_ib0['total_time'] / ddp_4_b_128_2_ib0['total_time']
ddp_8_b_128_2_ib0['speedup'] = ddp_8_b_128_ib0['total_time'] / ddp_8_b_128_2_ib0['total_time']

ddp_2_b_128_4_ib0['speedup'] = ddp_2_b_128_ib0['total_time'] / ddp_2_b_128_4_ib0['total_time']
ddp_4_b_128_4_ib0['speedup'] = ddp_4_b_128_ib0['total_time'] / ddp_4_b_128_4_ib0['total_time']
ddp_8_b_128_4_ib0['speedup'] = ddp_8_b_128_ib0['total_time'] / ddp_8_b_128_4_ib0['total_time']

ddp_2_b_128_8_ib0['speedup'] = ddp_2_b_128_ib0['total_time'] / ddp_2_b_128_8_ib0['total_time']
ddp_4_b_128_8_ib0['speedup'] = ddp_4_b_128_ib0['total_time'] / ddp_4_b_128_8_ib0['total_time']
ddp_8_b_128_8_ib0['speedup'] = ddp_8_b_128_ib0['total_time'] / ddp_8_b_128_8_ib0['total_time']

print("Speedup for 2 Workers with tau=2:", ddp_2_b_128_2_ib0['speedup'].mean())
print("Speedup for 4 Workers with tau=2:", ddp_4_b_128_2_ib0['speedup'].mean())
print("Speedup for 8 Workers with tau=2:", ddp_8_b_128_2_ib0['speedup'].mean())

print("Speedup for 2 Workers with tau=4:", ddp_2_b_128_4_ib0['speedup'].mean())
print("Speedup for 4 Workers with tau=4:", ddp_4_b_128_4_ib0['speedup'].mean())
print("Speedup for 8 Workers with tau=4:", ddp_8_b_128_4_ib0['speedup'].mean())

print("Speedup for 2 Workers with tau=8:", ddp_2_b_128_8_ib0['speedup'].mean())
print("Speedup for 4 Workers with tau=8:", ddp_4_b_128_8_ib0['speedup'].mean())
print("Speedup for 8 Workers with tau=8:", ddp_8_b_128_8_ib0['speedup'].mean())
# Out:
# Speedup for 2 Workers with tau=2: 1.0209273610400482
# Speedup for 4 Workers with tau=2: 1.127314495025606
# Speedup for 8 Workers with tau=2: 1.2525163759867262
# Speedup for 2 Workers with tau=4: 1.0221027699625436
# Speedup for 4 Workers with tau=4: 1.1510210604381488
# Speedup for 8 Workers with tau=4: 1.2831268799153543
# Speedup for 2 Workers with tau=8: 1.035516956244013
# Speedup for 4 Workers with tau=8: 1.1581327610633116
# Speedup for 8 Workers with tau=8: 1.317165388953184

# %% [markdown]
# ### 256

# %%
# Ethernet - 256
ddp_2_b_256_eth1 = pd.read_csv("../log/synch_ddp/rank_0_synch_ddp_2_minibatch_256_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_4_b_256_eth1 = pd.read_csv("../log/synch_ddp/rank_0_synch_ddp_4_minibatch_256_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_8_b_256_eth1 = pd.read_csv("../log/synch_ddp/rank_0_synch_ddp_8_minibatch_256_vit-base-patch16-224-in21k_model_eth1.csv")

ddp_2_b_256_eth1 = ddp_2_b_256_eth1[ddp_2_b_256_eth1['phase'] == 'train']
ddp_4_b_256_eth1 = ddp_4_b_256_eth1[ddp_4_b_256_eth1['phase'] == 'train']
ddp_8_b_256_eth1 = ddp_8_b_256_eth1[ddp_8_b_256_eth1['phase'] == 'train']

ddp_2_b_256_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_256_tau_2_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_4_b_256_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_256_tau_2_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_8_b_256_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_256_tau_2_vit-base-patch16-224-in21k_model_eth1.csv")

ddp_2_b_256_2_eth1 = ddp_2_b_256_2_eth1[ddp_2_b_256_2_eth1['phase'] == 'train']
ddp_4_b_256_2_eth1 = ddp_4_b_256_2_eth1[ddp_4_b_256_2_eth1['phase'] == 'train']
ddp_8_b_256_2_eth1 = ddp_8_b_256_2_eth1[ddp_8_b_256_2_eth1['phase'] == 'train']

ddp_2_b_256_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_256_tau_4_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_4_b_256_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_256_tau_4_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_8_b_256_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_256_tau_4_vit-base-patch16-224-in21k_model_eth1.csv")

ddp_2_b_256_4_eth1 = ddp_2_b_256_4_eth1[ddp_2_b_256_4_eth1['phase'] == 'train']
ddp_4_b_256_4_eth1 = ddp_4_b_256_4_eth1[ddp_4_b_256_4_eth1['phase'] == 'train']
ddp_8_b_256_4_eth1 = ddp_8_b_256_4_eth1[ddp_8_b_256_4_eth1['phase'] == 'train']

ddp_2_b_256_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_256_tau_8_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_4_b_256_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_256_tau_8_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_8_b_256_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_256_tau_8_vit-base-patch16-224-in21k_model_eth1.csv")

ddp_2_b_256_8_eth1 = ddp_2_b_256_8_eth1[ddp_2_b_256_8_eth1['phase'] == 'train']
ddp_4_b_256_8_eth1 = ddp_4_b_256_8_eth1[ddp_4_b_256_8_eth1['phase'] == 'train']
ddp_8_b_256_8_eth1 = ddp_8_b_256_8_eth1[ddp_8_b_256_8_eth1['phase'] == 'train']

ddp_2_b_256_eth1['total_time'] = ddp_2_b_256_eth1['forward_time'] + ddp_2_b_256_eth1['backward_time']
ddp_4_b_256_eth1['total_time'] = ddp_4_b_256_eth1['forward_time'] + ddp_4_b_256_eth1['backward_time']
ddp_8_b_256_eth1['total_time'] = ddp_8_b_256_eth1['forward_time'] + ddp_8_b_256_eth1['backward_time']
ddp_2_b_256_2_eth1['total_time'] = ddp_2_b_256_2_eth1['forward_time'] + ddp_2_b_256_2_eth1['backward_time'] + ddp_2_b_256_2_eth1['synch_avg_time']
ddp_4_b_256_2_eth1['total_time'] = ddp_4_b_256_2_eth1['forward_time'] + ddp_4_b_256_2_eth1['backward_time'] + ddp_4_b_256_2_eth1['synch_avg_time']
ddp_8_b_256_2_eth1['total_time'] = ddp_8_b_256_2_eth1['forward_time'] + ddp_8_b_256_2_eth1['backward_time'] + ddp_8_b_256_2_eth1['synch_avg_time']
ddp_2_b_256_4_eth1['total_time'] = ddp_2_b_256_4_eth1['forward_time'] + ddp_2_b_256_4_eth1['backward_time'] + ddp_2_b_256_4_eth1['synch_avg_time']
ddp_4_b_256_4_eth1['total_time'] = ddp_4_b_256_4_eth1['forward_time'] + ddp_4_b_256_4_eth1['backward_time'] + ddp_4_b_256_4_eth1['synch_avg_time']
ddp_8_b_256_4_eth1['total_time'] = ddp_8_b_256_4_eth1['forward_time'] + ddp_8_b_256_4_eth1['backward_time'] + ddp_8_b_256_4_eth1['synch_avg_time']
ddp_2_b_256_8_eth1['total_time'] = ddp_2_b_256_8_eth1['forward_time'] + ddp_2_b_256_8_eth1['backward_time'] + ddp_2_b_256_8_eth1['synch_avg_time']
ddp_4_b_256_8_eth1['total_time'] = ddp_4_b_256_8_eth1['forward_time'] + ddp_4_b_256_8_eth1['backward_time'] + ddp_4_b_256_8_eth1['synch_avg_time']
ddp_8_b_256_8_eth1['total_time'] = ddp_8_b_256_8_eth1['forward_time'] + ddp_8_b_256_8_eth1['backward_time'] + ddp_8_b_256_8_eth1['synch_avg_time']

ddp_2_b_256_2_eth1['speedup'] = ddp_2_b_256_eth1['total_time'] / ddp_2_b_256_2_eth1['total_time']
ddp_4_b_256_2_eth1['speedup'] = ddp_4_b_256_eth1['total_time'] / ddp_4_b_256_2_eth1['total_time']
ddp_8_b_256_2_eth1['speedup'] = ddp_8_b_256_eth1['total_time'] / ddp_8_b_256_2_eth1['total_time']

ddp_2_b_256_4_eth1['speedup'] = ddp_2_b_256_eth1['total_time'] / ddp_2_b_256_4_eth1['total_time']
ddp_4_b_256_4_eth1['speedup'] = ddp_4_b_256_eth1['total_time'] / ddp_4_b_256_4_eth1['total_time']
ddp_8_b_256_4_eth1['speedup'] = ddp_8_b_256_eth1['total_time'] / ddp_8_b_256_4_eth1['total_time']

ddp_2_b_256_8_eth1['speedup'] = ddp_2_b_256_eth1['total_time'] / ddp_2_b_256_8_eth1['total_time']
ddp_4_b_256_8_eth1['speedup'] = ddp_4_b_256_eth1['total_time'] / ddp_4_b_256_8_eth1['total_time']
ddp_8_b_256_8_eth1['speedup'] = ddp_8_b_256_eth1['total_time'] / ddp_8_b_256_8_eth1['total_time']

print("Speedup for 2 Workers with tau=2:", ddp_2_b_256_2_eth1['speedup'].mean())
print("Speedup for 4 Workers with tau=2:", ddp_4_b_256_2_eth1['speedup'].mean())
print("Speedup for 8 Workers with tau=2:", ddp_8_b_256_2_eth1['speedup'].mean())

print("Speedup for 2 Workers with tau=4:", ddp_2_b_256_4_eth1['speedup'].mean())
print("Speedup for 4 Workers with tau=4:", ddp_4_b_256_4_eth1['speedup'].mean())
print("Speedup for 8 Workers with tau=4:", ddp_8_b_256_4_eth1['speedup'].mean())

print("Speedup for 2 Workers with tau=8:", ddp_2_b_256_8_eth1['speedup'].mean())
print("Speedup for 4 Workers with tau=8:", ddp_4_b_256_8_eth1['speedup'].mean())
print("Speedup for 8 Workers with tau=8:", ddp_8_b_256_8_eth1['speedup'].mean())
# Out:
# Speedup for 2 Workers with tau=2: 1.0138030129219489
# Speedup for 4 Workers with tau=2: 1.0708928598748064
# Speedup for 8 Workers with tau=2: 1.142148707185332
# Speedup for 2 Workers with tau=4: 1.026686964326641
# Speedup for 4 Workers with tau=4: 1.095101035778439
# Speedup for 8 Workers with tau=4: 1.1903867079874995
# Speedup for 2 Workers with tau=8: 1.0285992174839627
# Speedup for 4 Workers with tau=8: 1.1055375726663628
# Speedup for 8 Workers with tau=8: 1.2265455744810574

# %% [markdown]
# ## Large

# %% [markdown]
# ## Huge
