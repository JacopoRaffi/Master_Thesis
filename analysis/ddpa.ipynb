# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from plot_utils import *

# %%
plt.rcParams['font.size'] = 20

# %% [markdown]
# ## PLOT DA FARE:
# 1. Fai le curve come il sincrono e tieni i tau separati
# 2. Misura quanto eth1 e ib0 ci mettono a sincronizzare i vari modelli...fai un codice apparte per ciò

# %% [markdown]
# # Minibatch Comparison

# %% [markdown]
# ## Base

# %%
ddp_1_b_64_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_1_minibatch_64_tau_2_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_2_b_64_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_64_tau_2_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_4_b_64_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_64_tau_2_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_8_b_64_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_64_tau_2_vit-base-patch16-224-in21k_model_eth1.csv")

ddp_2_b_64_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_64_tau_2_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_4_b_64_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_64_tau_2_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_8_b_64_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_64_tau_2_vit-base-patch16-224-in21k_model_ib0.csv")

ddp_1_b_64_2_eth1 = ddp_1_b_64_2_eth1[ddp_1_b_64_2_eth1['phase'] == 'train']
ddp_2_b_64_2_eth1 = ddp_2_b_64_2_eth1[ddp_2_b_64_2_eth1['phase'] == 'train']
ddp_4_b_64_2_eth1 = ddp_4_b_64_2_eth1[ddp_4_b_64_2_eth1['phase'] == 'train']
ddp_8_b_64_2_eth1 = ddp_8_b_64_2_eth1[ddp_8_b_64_2_eth1['phase'] == 'train']

ddp_2_b_64_2_ib0 = ddp_2_b_64_2_ib0[ddp_2_b_64_2_ib0['phase'] == 'train']
ddp_4_b_64_2_ib0 = ddp_4_b_64_2_ib0[ddp_4_b_64_2_ib0['phase'] == 'train']
ddp_8_b_64_2_ib0 = ddp_8_b_64_2_ib0[ddp_8_b_64_2_ib0['phase'] == 'train']

# ------------------------------- TAU 4 ---------------------------------------------------
ddp_1_b_64_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_1_minibatch_64_tau_4_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_2_b_64_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_64_tau_4_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_4_b_64_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_64_tau_4_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_8_b_64_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_64_tau_4_vit-base-patch16-224-in21k_model_eth1.csv")

ddp_2_b_64_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_64_tau_4_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_4_b_64_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_64_tau_4_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_8_b_64_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_64_tau_4_vit-base-patch16-224-in21k_model_ib0.csv")

ddp_1_b_64_4_eth1 = ddp_1_b_64_4_eth1[ddp_1_b_64_4_eth1['phase'] == 'train']
ddp_2_b_64_4_eth1 = ddp_2_b_64_4_eth1[ddp_2_b_64_4_eth1['phase'] == 'train']
ddp_4_b_64_4_eth1 = ddp_4_b_64_4_eth1[ddp_4_b_64_4_eth1['phase'] == 'train']
ddp_8_b_64_4_eth1 = ddp_8_b_64_4_eth1[ddp_8_b_64_4_eth1['phase'] == 'train']

ddp_2_b_64_4_ib0 = ddp_2_b_64_4_ib0[ddp_2_b_64_4_ib0['phase'] == 'train']
ddp_4_b_64_4_ib0 = ddp_4_b_64_4_ib0[ddp_4_b_64_4_ib0['phase'] == 'train']
ddp_8_b_64_4_ib0 = ddp_8_b_64_4_ib0[ddp_8_b_64_4_ib0['phase'] == 'train']

# ----------------------------------- TAU 8 ----------------------------------------------------
ddp_1_b_64_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_1_minibatch_64_tau_8_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_2_b_64_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_64_tau_8_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_4_b_64_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_64_tau_8_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_8_b_64_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_64_tau_8_vit-base-patch16-224-in21k_model_eth1.csv")

ddp_2_b_64_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_64_tau_8_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_4_b_64_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_64_tau_8_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_8_b_64_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_64_tau_8_vit-base-patch16-224-in21k_model_ib0.csv")

ddp_1_b_64_8_eth1 = ddp_1_b_64_8_eth1[ddp_1_b_64_8_eth1['phase'] == 'train']
ddp_2_b_64_8_eth1 = ddp_2_b_64_8_eth1[ddp_2_b_64_8_eth1['phase'] == 'train']
ddp_4_b_64_8_eth1 = ddp_4_b_64_8_eth1[ddp_4_b_64_8_eth1['phase'] == 'train']
ddp_8_b_64_8_eth1 = ddp_8_b_64_8_eth1[ddp_8_b_64_8_eth1['phase'] == 'train']

ddp_2_b_64_8_ib0 = ddp_2_b_64_8_ib0[ddp_2_b_64_8_ib0['phase'] == 'train']
ddp_4_b_64_8_ib0 = ddp_4_b_64_8_ib0[ddp_4_b_64_8_ib0['phase'] == 'train']
ddp_8_b_64_8_ib0 = ddp_8_b_64_8_ib0[ddp_8_b_64_8_ib0['phase'] == 'train']

# %%
plt.figure(figsize=(10,6))
plot_speedup([ddp_1_b_64_2_eth1, ddp_2_b_64_2_eth1, ddp_4_b_64_2_eth1, ddp_8_b_64_2_eth1], "ViT-Base - Minibatch 64 - Tau 2", "Ethernet", color='blue', plot_ideal=False, asynch=True)
plot_speedup([ddp_1_b_64_2_eth1, ddp_2_b_64_2_ib0, ddp_4_b_64_2_ib0, ddp_8_b_64_2_ib0], "ViT-Base - Minibatch 64 - Tau 2", "OPX", color='red', plot_ideal=True, asynch=True)
plt.tight_layout()

# %%
plt.figure(figsize=(10,6))
plot_speedup([ddp_1_b_64_4_eth1, ddp_2_b_64_4_eth1, ddp_4_b_64_4_eth1, ddp_8_b_64_4_eth1], "ViT-Base - Minibatch 64 - Tau 4", "Ethernet", color='blue', plot_ideal=False, asynch=True)
plot_speedup([ddp_1_b_64_4_eth1, ddp_2_b_64_4_ib0, ddp_4_b_64_4_ib0, ddp_8_b_64_4_ib0], "ViT-Base - Minibatch 64 - Tau 4", "OPX", color='red', plot_ideal=True, asynch=True)
plt.tight_layout()

# %%
plt.figure(figsize=(10,6))
plot_speedup([ddp_1_b_64_8_eth1, ddp_2_b_64_8_eth1, ddp_4_b_64_8_eth1, ddp_8_b_64_8_eth1], "ViT-Base - Minibatch 64 - Tau 8", "Ethernet", color='blue', plot_ideal=False, asynch=True)
plot_speedup([ddp_1_b_64_8_eth1, ddp_2_b_64_8_ib0, ddp_4_b_64_8_ib0, ddp_8_b_64_8_ib0], "ViT-Base - Minibatch 64 - Tau 8", "OPX", color='red', plot_ideal=True, asynch=True)
plt.tight_layout()

# %%
ddp_1_b_128_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_1_minibatch_128_tau_2_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_2_b_128_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_128_tau_2_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_4_b_128_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_128_tau_2_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_8_b_128_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_128_tau_2_vit-base-patch16-224-in21k_model_eth1.csv")

ddp_2_b_128_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_128_tau_2_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_4_b_128_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_128_tau_2_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_8_b_128_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_128_tau_2_vit-base-patch16-224-in21k_model_ib0.csv")

ddp_1_b_128_2_eth1 = ddp_1_b_128_2_eth1[ddp_1_b_128_2_eth1['phase'] == 'train']
ddp_2_b_128_2_eth1 = ddp_2_b_128_2_eth1[ddp_2_b_128_2_eth1['phase'] == 'train']
ddp_4_b_128_2_eth1 = ddp_4_b_128_2_eth1[ddp_4_b_128_2_eth1['phase'] == 'train']
ddp_8_b_128_2_eth1 = ddp_8_b_128_2_eth1[ddp_8_b_128_2_eth1['phase'] == 'train']

ddp_2_b_128_2_ib0 = ddp_2_b_128_2_ib0[ddp_2_b_128_2_ib0['phase'] == 'train']
ddp_4_b_128_2_ib0 = ddp_4_b_128_2_ib0[ddp_4_b_128_2_ib0['phase'] == 'train']
ddp_8_b_128_2_ib0 = ddp_8_b_128_2_ib0[ddp_8_b_128_2_ib0['phase'] == 'train']

# ------------------------------- TAU 4 ---------------------------------------------------
ddp_1_b_128_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_1_minibatch_128_tau_4_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_2_b_128_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_128_tau_4_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_4_b_128_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_128_tau_4_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_8_b_128_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_128_tau_4_vit-base-patch16-224-in21k_model_eth1.csv")

ddp_2_b_128_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_128_tau_4_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_4_b_128_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_128_tau_4_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_8_b_128_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_128_tau_4_vit-base-patch16-224-in21k_model_ib0.csv")

ddp_1_b_128_4_eth1 = ddp_1_b_128_4_eth1[ddp_1_b_128_4_eth1['phase'] == 'train']
ddp_2_b_128_4_eth1 = ddp_2_b_128_4_eth1[ddp_2_b_128_4_eth1['phase'] == 'train']
ddp_4_b_128_4_eth1 = ddp_4_b_128_4_eth1[ddp_4_b_128_4_eth1['phase'] == 'train']
ddp_8_b_128_4_eth1 = ddp_8_b_128_4_eth1[ddp_8_b_128_4_eth1['phase'] == 'train']

ddp_2_b_128_4_ib0 = ddp_2_b_128_4_ib0[ddp_2_b_128_4_ib0['phase'] == 'train']
ddp_4_b_128_4_ib0 = ddp_4_b_128_4_ib0[ddp_4_b_128_4_ib0['phase'] == 'train']
ddp_8_b_128_4_ib0 = ddp_8_b_128_4_ib0[ddp_8_b_128_4_ib0['phase'] == 'train']

# ----------------------------------- TAU 8 ----------------------------------------------------
ddp_1_b_128_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_1_minibatch_128_tau_8_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_2_b_128_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_128_tau_8_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_4_b_128_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_128_tau_8_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_8_b_128_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_128_tau_8_vit-base-patch16-224-in21k_model_eth1.csv")

ddp_2_b_128_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_128_tau_8_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_4_b_128_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_128_tau_8_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_8_b_128_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_128_tau_8_vit-base-patch16-224-in21k_model_ib0.csv")

ddp_1_b_128_8_eth1 = ddp_1_b_128_8_eth1[ddp_1_b_128_8_eth1['phase'] == 'train']
ddp_2_b_128_8_eth1 = ddp_2_b_128_8_eth1[ddp_2_b_128_8_eth1['phase'] == 'train']
ddp_4_b_128_8_eth1 = ddp_4_b_128_8_eth1[ddp_4_b_128_8_eth1['phase'] == 'train']
ddp_8_b_128_8_eth1 = ddp_8_b_128_8_eth1[ddp_8_b_128_8_eth1['phase'] == 'train']

ddp_2_b_128_8_ib0 = ddp_2_b_128_8_ib0[ddp_2_b_128_8_ib0['phase'] == 'train']
ddp_4_b_128_8_ib0 = ddp_4_b_128_8_ib0[ddp_4_b_128_8_ib0['phase'] == 'train']
ddp_8_b_128_8_ib0 = ddp_8_b_128_8_ib0[ddp_8_b_128_8_ib0['phase'] == 'train']

# %%
plt.figure(figsize=(10,6))
plot_speedup([ddp_1_b_128_2_eth1, ddp_2_b_128_2_eth1, ddp_4_b_128_2_eth1, ddp_8_b_128_2_eth1], "ViT-Base - Minibatch 128 - Tau 2", "Ethernet", color='blue', plot_ideal=False, asynch=True)
plot_speedup([ddp_1_b_128_2_eth1, ddp_2_b_128_2_ib0, ddp_4_b_128_2_ib0, ddp_8_b_128_2_ib0], "ViT-Base - Minibatch 128 - Tau 2", "OPX", color='red', plot_ideal=True, asynch=True)
plt.tight_layout()

# %%
plt.figure(figsize=(10,6))
plot_speedup([ddp_1_b_128_4_eth1, ddp_2_b_128_4_eth1, ddp_4_b_128_4_eth1, ddp_8_b_128_4_eth1], "ViT-Base - Minibatch 128 - Tau 4", "Ethernet", color='blue', plot_ideal=False, asynch=True)
plot_speedup([ddp_1_b_128_4_eth1, ddp_2_b_128_4_ib0, ddp_4_b_128_4_ib0, ddp_8_b_128_4_ib0], "ViT-Base - Minibatch 128 - Tau 4", "OPX", color='red', plot_ideal=True, asynch=True)
plt.tight_layout()

# %%
plt.figure(figsize=(10,6))
plot_speedup([ddp_1_b_128_8_eth1, ddp_2_b_128_8_eth1, ddp_4_b_128_8_eth1, ddp_8_b_128_8_eth1], "ViT-Base - Minibatch 128 - Tau 8", "Ethernet", color='blue', plot_ideal=False, asynch=True)
plot_speedup([ddp_1_b_128_8_eth1, ddp_2_b_128_8_ib0, ddp_4_b_128_8_ib0, ddp_8_b_128_8_ib0], "ViT-Base - Minibatch 128 - Tau 8", "OPX", color='red', plot_ideal=True, asynch=True)
plt.tight_layout()

# %%
ddp_1_b_256_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_1_minibatch_256_tau_2_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_2_b_256_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_256_tau_2_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_4_b_256_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_256_tau_2_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_8_b_256_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_256_tau_2_vit-base-patch16-224-in21k_model_eth1.csv")

ddp_2_b_256_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_256_tau_2_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_4_b_256_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_256_tau_2_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_8_b_256_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_256_tau_2_vit-base-patch16-224-in21k_model_ib0.csv")

ddp_1_b_256_2_eth1 = ddp_1_b_256_2_eth1[ddp_1_b_256_2_eth1['phase'] == 'train']
ddp_2_b_256_2_eth1 = ddp_2_b_256_2_eth1[ddp_2_b_256_2_eth1['phase'] == 'train']
ddp_4_b_256_2_eth1 = ddp_4_b_256_2_eth1[ddp_4_b_256_2_eth1['phase'] == 'train']
ddp_8_b_256_2_eth1 = ddp_8_b_256_2_eth1[ddp_8_b_256_2_eth1['phase'] == 'train']

ddp_2_b_256_2_ib0 = ddp_2_b_256_2_ib0[ddp_2_b_256_2_ib0['phase'] == 'train']
ddp_4_b_256_2_ib0 = ddp_4_b_256_2_ib0[ddp_4_b_256_2_ib0['phase'] == 'train']
ddp_8_b_256_2_ib0 = ddp_8_b_256_2_ib0[ddp_8_b_256_2_ib0['phase'] == 'train']

# ------------------------------- TAU 4 ---------------------------------------------------
ddp_1_b_256_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_1_minibatch_256_tau_4_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_2_b_256_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_256_tau_4_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_4_b_256_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_256_tau_4_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_8_b_256_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_256_tau_4_vit-base-patch16-224-in21k_model_eth1.csv")

ddp_2_b_256_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_256_tau_4_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_4_b_256_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_256_tau_4_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_8_b_256_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_256_tau_4_vit-base-patch16-224-in21k_model_ib0.csv")

ddp_1_b_256_4_eth1 = ddp_1_b_256_4_eth1[ddp_1_b_256_4_eth1['phase'] == 'train']
ddp_2_b_256_4_eth1 = ddp_2_b_256_4_eth1[ddp_2_b_256_4_eth1['phase'] == 'train']
ddp_4_b_256_4_eth1 = ddp_4_b_256_4_eth1[ddp_4_b_256_4_eth1['phase'] == 'train']
ddp_8_b_256_4_eth1 = ddp_8_b_256_4_eth1[ddp_8_b_256_4_eth1['phase'] == 'train']

ddp_2_b_256_4_ib0 = ddp_2_b_256_4_ib0[ddp_2_b_256_4_ib0['phase'] == 'train']
ddp_4_b_256_4_ib0 = ddp_4_b_256_4_ib0[ddp_4_b_256_4_ib0['phase'] == 'train']
ddp_8_b_256_4_ib0 = ddp_8_b_256_4_ib0[ddp_8_b_256_4_ib0['phase'] == 'train']

# ----------------------------------- TAU 8 ----------------------------------------------------
ddp_1_b_256_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_1_minibatch_256_tau_8_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_2_b_256_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_256_tau_8_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_4_b_256_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_256_tau_8_vit-base-patch16-224-in21k_model_eth1.csv")
ddp_8_b_256_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_256_tau_8_vit-base-patch16-224-in21k_model_eth1.csv")

ddp_2_b_256_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_256_tau_8_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_4_b_256_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_256_tau_8_vit-base-patch16-224-in21k_model_ib0.csv")
ddp_8_b_256_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_256_tau_8_vit-base-patch16-224-in21k_model_ib0.csv")

ddp_1_b_256_8_eth1 = ddp_1_b_256_8_eth1[ddp_1_b_256_8_eth1['phase'] == 'train']
ddp_2_b_256_8_eth1 = ddp_2_b_256_8_eth1[ddp_2_b_256_8_eth1['phase'] == 'train']
ddp_4_b_256_8_eth1 = ddp_4_b_256_8_eth1[ddp_4_b_256_8_eth1['phase'] == 'train']
ddp_8_b_256_8_eth1 = ddp_8_b_256_8_eth1[ddp_8_b_256_8_eth1['phase'] == 'train']

ddp_2_b_256_8_ib0 = ddp_2_b_256_8_ib0[ddp_2_b_256_8_ib0['phase'] == 'train']
ddp_4_b_256_8_ib0 = ddp_4_b_256_8_ib0[ddp_4_b_256_8_ib0['phase'] == 'train']
ddp_8_b_256_8_ib0 = ddp_8_b_256_8_ib0[ddp_8_b_256_8_ib0['phase'] == 'train']

# %%
plt.figure(figsize=(10,6))
plot_speedup([ddp_1_b_256_2_eth1, ddp_2_b_256_2_eth1, ddp_4_b_256_2_eth1, ddp_8_b_256_2_eth1], "ViT-Base - Minibatch 256 - Tau 2", "Ethernet", color='blue', plot_ideal=False, asynch=True)
plot_speedup([ddp_1_b_256_2_eth1, ddp_2_b_256_2_ib0, ddp_4_b_256_2_ib0, ddp_8_b_256_2_ib0], "ViT-Base - Minibatch 256 - Tau 2", "OPX", color='red', plot_ideal=True, asynch=True)
plt.tight_layout()

# %%
plt.figure(figsize=(10,6))
plot_speedup([ddp_1_b_256_4_eth1, ddp_2_b_256_4_eth1, ddp_4_b_256_4_eth1, ddp_8_b_256_4_eth1], "ViT-Base - Minibatch 256 - Tau 4", "Ethernet", color='blue', plot_ideal=False, asynch=True)
plot_speedup([ddp_1_b_256_4_eth1, ddp_2_b_256_4_ib0, ddp_4_b_256_4_ib0, ddp_8_b_256_4_ib0], "ViT-Base - Minibatch 256 - Tau 4", "OPX", color='red', plot_ideal=True, asynch=True)
plt.tight_layout()

# %%
plt.figure(figsize=(10,6))
plot_speedup([ddp_1_b_256_8_eth1, ddp_2_b_256_8_eth1, ddp_4_b_256_8_eth1, ddp_8_b_256_8_eth1], "ViT-Base - Minibatch 256 - Tau 8", "Ethernet", color='blue', plot_ideal=False, asynch=True)
plot_speedup([ddp_1_b_256_8_eth1, ddp_2_b_256_8_ib0, ddp_4_b_256_8_ib0, ddp_8_b_256_8_ib0], "ViT-Base - Minibatch 256 - Tau 8", "OPX", color='red', plot_ideal=True, asynch=True)
plt.tight_layout()

# %% [markdown]
# ## Large

# %%
ddp_1_l_64_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_1_minibatch_64_tau_2_vit-large-patch16-224-in21k_model_eth1.csv")
ddp_2_l_64_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_64_tau_2_vit-large-patch16-224-in21k_model_eth1.csv")
ddp_4_l_64_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_64_tau_2_vit-large-patch16-224-in21k_model_eth1.csv")
ddp_8_l_64_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_64_tau_2_vit-large-patch16-224-in21k_model_eth1.csv")

ddp_2_l_64_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_64_tau_2_vit-large-patch16-224-in21k_model_ib0.csv")
ddp_4_l_64_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_64_tau_2_vit-large-patch16-224-in21k_model_ib0.csv")
ddp_8_l_64_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_64_tau_2_vit-large-patch16-224-in21k_model_ib0.csv")

ddp_1_l_64_2_eth1 = ddp_1_l_64_2_eth1[ddp_1_l_64_2_eth1['phase'] == 'train']
ddp_2_l_64_2_eth1 = ddp_2_l_64_2_eth1[ddp_2_l_64_2_eth1['phase'] == 'train']
ddp_4_l_64_2_eth1 = ddp_4_l_64_2_eth1[ddp_4_l_64_2_eth1['phase'] == 'train']
ddp_8_l_64_2_eth1 = ddp_8_l_64_2_eth1[ddp_8_l_64_2_eth1['phase'] == 'train']

ddp_2_l_64_2_ib0 = ddp_2_l_64_2_ib0[ddp_2_l_64_2_ib0['phase'] == 'train']
ddp_4_l_64_2_ib0 = ddp_4_l_64_2_ib0[ddp_4_l_64_2_ib0['phase'] == 'train']
ddp_8_l_64_2_ib0 = ddp_8_l_64_2_ib0[ddp_8_l_64_2_ib0['phase'] == 'train']

# ------------------------------- TAU 4 ---------------------------------------------------
ddp_1_l_64_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_1_minibatch_64_tau_4_vit-large-patch16-224-in21k_model_eth1.csv")
ddp_2_l_64_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_64_tau_4_vit-large-patch16-224-in21k_model_eth1.csv")
ddp_4_l_64_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_64_tau_4_vit-large-patch16-224-in21k_model_eth1.csv")
ddp_8_l_64_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_64_tau_4_vit-large-patch16-224-in21k_model_eth1.csv")

ddp_2_l_64_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_64_tau_4_vit-large-patch16-224-in21k_model_ib0.csv")
ddp_4_l_64_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_64_tau_4_vit-large-patch16-224-in21k_model_ib0.csv")
ddp_8_l_64_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_64_tau_4_vit-large-patch16-224-in21k_model_ib0.csv")

ddp_1_l_64_4_eth1 = ddp_1_l_64_4_eth1[ddp_1_l_64_4_eth1['phase'] == 'train']
ddp_2_l_64_4_eth1 = ddp_2_l_64_4_eth1[ddp_2_l_64_4_eth1['phase'] == 'train']
ddp_4_l_64_4_eth1 = ddp_4_l_64_4_eth1[ddp_4_l_64_4_eth1['phase'] == 'train']
ddp_8_l_64_4_eth1 = ddp_8_l_64_4_eth1[ddp_8_l_64_4_eth1['phase'] == 'train']

ddp_2_l_64_4_ib0 = ddp_2_l_64_4_ib0[ddp_2_l_64_4_ib0['phase'] == 'train']
ddp_4_l_64_4_ib0 = ddp_4_l_64_4_ib0[ddp_4_l_64_4_ib0['phase'] == 'train']
ddp_8_l_64_4_ib0 = ddp_8_l_64_4_ib0[ddp_8_l_64_4_ib0['phase'] == 'train']

# ----------------------------------- TAU 8 ----------------------------------------------------
ddp_1_l_64_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_1_minibatch_64_tau_8_vit-large-patch16-224-in21k_model_eth1.csv")
ddp_2_l_64_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_64_tau_8_vit-large-patch16-224-in21k_model_eth1.csv")
ddp_4_l_64_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_64_tau_8_vit-large-patch16-224-in21k_model_eth1.csv")
ddp_8_l_64_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_64_tau_8_vit-large-patch16-224-in21k_model_eth1.csv")

ddp_2_l_64_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_64_tau_8_vit-large-patch16-224-in21k_model_ib0.csv")
ddp_4_l_64_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_64_tau_8_vit-large-patch16-224-in21k_model_ib0.csv")
ddp_8_l_64_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_64_tau_8_vit-large-patch16-224-in21k_model_ib0.csv")

ddp_1_l_64_8_eth1 = ddp_1_l_64_8_eth1[ddp_1_l_64_8_eth1['phase'] == 'train']
ddp_2_l_64_8_eth1 = ddp_2_l_64_8_eth1[ddp_2_l_64_8_eth1['phase'] == 'train']
ddp_4_l_64_8_eth1 = ddp_4_l_64_8_eth1[ddp_4_l_64_8_eth1['phase'] == 'train']
ddp_8_l_64_8_eth1 = ddp_8_l_64_8_eth1[ddp_8_l_64_8_eth1['phase'] == 'train']

ddp_2_l_64_8_ib0 = ddp_2_l_64_8_ib0[ddp_2_l_64_8_ib0['phase'] == 'train']
ddp_4_l_64_8_ib0 = ddp_4_l_64_8_ib0[ddp_4_l_64_8_ib0['phase'] == 'train']
ddp_8_l_64_8_ib0 = ddp_8_l_64_8_ib0[ddp_8_l_64_8_ib0['phase'] == 'train']

# %%
plt.figure(figsize=(10,6))
plot_speedup([ddp_1_l_64_2_eth1, ddp_2_l_64_2_eth1, ddp_4_l_64_2_eth1, ddp_8_l_64_2_eth1], "ViT-Large - Minibatch 64 - Tau 2", "Ethernet", color='blue', plot_ideal=False, asynch=True)
plot_speedup([ddp_1_l_64_2_eth1, ddp_2_l_64_2_ib0, ddp_4_l_64_2_ib0, ddp_8_l_64_2_ib0], "ViT-Large - Minibatch 64 - Tau 2", "OPX", color='red', plot_ideal=True, asynch=True)
plt.tight_layout()

# %%
plt.figure(figsize=(10,6))
plot_speedup([ddp_1_l_64_4_eth1, ddp_2_l_64_4_eth1, ddp_4_l_64_4_eth1, ddp_8_l_64_4_eth1], "ViT-Large - Minibatch 64 - Tau 4", "Ethernet", color='blue', plot_ideal=False, asynch=True)
plot_speedup([ddp_1_l_64_4_eth1, ddp_2_l_64_4_ib0, ddp_4_l_64_4_ib0, ddp_8_l_64_4_ib0], "ViT-Large - Minibatch 64 - Tau 4", "OPX", color='red', plot_ideal=True, asynch=True)
plt.tight_layout()

# %%
plt.figure(figsize=(10,6))
plot_speedup([ddp_1_l_64_8_eth1, ddp_2_l_64_8_eth1, ddp_4_l_64_8_eth1, ddp_8_l_64_8_eth1], "ViT-Large - Minibatch 64 - Tau 8", "Ethernet", color='blue', plot_ideal=False, asynch=True)
plot_speedup([ddp_1_l_64_8_eth1, ddp_2_l_64_8_ib0, ddp_4_l_64_8_ib0, ddp_8_l_64_8_ib0], "ViT-Large - Minibatch 64 - Tau 8", "OPX", color='red', plot_ideal=True, asynch=True)
plt.tight_layout()

# %%
ddp_1_l_128_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_1_minibatch_128_tau_2_vit-large-patch16-224-in21k_model_eth1.csv")
ddp_2_l_128_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_128_tau_2_vit-large-patch16-224-in21k_model_eth1.csv")
ddp_4_l_128_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_128_tau_2_vit-large-patch16-224-in21k_model_eth1.csv")
ddp_8_l_128_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_128_tau_2_vit-large-patch16-224-in21k_model_eth1.csv")

ddp_2_l_128_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_128_tau_2_vit-large-patch16-224-in21k_model_ib0.csv")
ddp_4_l_128_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_128_tau_2_vit-large-patch16-224-in21k_model_ib0.csv")
ddp_8_l_128_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_128_tau_2_vit-large-patch16-224-in21k_model_ib0.csv")

ddp_1_l_128_2_eth1 = ddp_1_l_128_2_eth1[ddp_1_l_128_2_eth1['phase'] == 'train']
ddp_2_l_128_2_eth1 = ddp_2_l_128_2_eth1[ddp_2_l_128_2_eth1['phase'] == 'train']
ddp_4_l_128_2_eth1 = ddp_4_l_128_2_eth1[ddp_4_l_128_2_eth1['phase'] == 'train']
ddp_8_l_128_2_eth1 = ddp_8_l_128_2_eth1[ddp_8_l_128_2_eth1['phase'] == 'train']

ddp_2_l_128_2_ib0 = ddp_2_l_128_2_ib0[ddp_2_l_128_2_ib0['phase'] == 'train']
ddp_4_l_128_2_ib0 = ddp_4_l_128_2_ib0[ddp_4_l_128_2_ib0['phase'] == 'train']
ddp_8_l_128_2_ib0 = ddp_8_l_128_2_ib0[ddp_8_l_128_2_ib0['phase'] == 'train']

# ------------------------------- TAU 4 ---------------------------------------------------
ddp_1_l_128_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_1_minibatch_128_tau_4_vit-large-patch16-224-in21k_model_eth1.csv")
ddp_2_l_128_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_128_tau_4_vit-large-patch16-224-in21k_model_eth1.csv")
ddp_4_l_128_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_128_tau_4_vit-large-patch16-224-in21k_model_eth1.csv")
ddp_8_l_128_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_128_tau_4_vit-large-patch16-224-in21k_model_eth1.csv")

ddp_2_l_128_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_128_tau_4_vit-large-patch16-224-in21k_model_ib0.csv")
ddp_4_l_128_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_128_tau_4_vit-large-patch16-224-in21k_model_ib0.csv")
ddp_8_l_128_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_128_tau_4_vit-large-patch16-224-in21k_model_ib0.csv")

ddp_1_l_128_4_eth1 = ddp_1_l_128_4_eth1[ddp_1_l_128_4_eth1['phase'] == 'train']
ddp_2_l_128_4_eth1 = ddp_2_l_128_4_eth1[ddp_2_l_128_4_eth1['phase'] == 'train']
ddp_4_l_128_4_eth1 = ddp_4_l_128_4_eth1[ddp_4_l_128_4_eth1['phase'] == 'train']
ddp_8_l_128_4_eth1 = ddp_8_l_128_4_eth1[ddp_8_l_128_4_eth1['phase'] == 'train']

ddp_2_l_128_4_ib0 = ddp_2_l_128_4_ib0[ddp_2_l_128_4_ib0['phase'] == 'train']
ddp_4_l_128_4_ib0 = ddp_4_l_128_4_ib0[ddp_4_l_128_4_ib0['phase'] == 'train']
ddp_8_l_128_4_ib0 = ddp_8_l_128_4_ib0[ddp_8_l_128_4_ib0['phase'] == 'train']

# ----------------------------------- TAU 8 ----------------------------------------------------
ddp_1_l_128_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_1_minibatch_128_tau_8_vit-large-patch16-224-in21k_model_eth1.csv")
ddp_2_l_128_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_128_tau_8_vit-large-patch16-224-in21k_model_eth1.csv")
ddp_4_l_128_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_128_tau_8_vit-large-patch16-224-in21k_model_eth1.csv")
ddp_8_l_128_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_128_tau_8_vit-large-patch16-224-in21k_model_eth1.csv")

ddp_2_l_128_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_128_tau_8_vit-large-patch16-224-in21k_model_ib0.csv")
ddp_4_l_128_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_128_tau_8_vit-large-patch16-224-in21k_model_ib0.csv")
ddp_8_l_128_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_128_tau_8_vit-large-patch16-224-in21k_model_ib0.csv")

ddp_1_l_128_8_eth1 = ddp_1_l_128_8_eth1[ddp_1_l_128_8_eth1['phase'] == 'train']
ddp_2_l_128_8_eth1 = ddp_2_l_128_8_eth1[ddp_2_l_128_8_eth1['phase'] == 'train']
ddp_4_l_128_8_eth1 = ddp_4_l_128_8_eth1[ddp_4_l_128_8_eth1['phase'] == 'train']
ddp_8_l_128_8_eth1 = ddp_8_l_128_8_eth1[ddp_8_l_128_8_eth1['phase'] == 'train']

ddp_2_l_128_8_ib0 = ddp_2_l_128_8_ib0[ddp_2_l_128_8_ib0['phase'] == 'train']
ddp_4_l_128_8_ib0 = ddp_4_l_128_8_ib0[ddp_4_l_128_8_ib0['phase'] == 'train']
ddp_8_l_128_8_ib0 = ddp_8_l_128_8_ib0[ddp_8_l_128_8_ib0['phase'] == 'train']

# %%
plt.figure(figsize=(10,6))
plot_speedup([ddp_1_l_128_2_eth1, ddp_2_l_128_2_eth1, ddp_4_l_128_2_eth1, ddp_8_l_128_2_eth1], "ViT-Large - Minibatch 128 - Tau 2", "Ethernet", color='blue', plot_ideal=False, asynch=True)
plot_speedup([ddp_1_l_128_2_eth1, ddp_2_l_128_2_ib0, ddp_4_l_128_2_ib0, ddp_8_l_128_2_ib0], "ViT-Large - Minibatch 128 - Tau 2", "OPX", color='red', plot_ideal=True, asynch=True)
plt.tight_layout()

# %%
plt.figure(figsize=(10,6))
plot_speedup([ddp_1_l_128_4_eth1, ddp_2_l_128_4_eth1, ddp_4_l_128_4_eth1, ddp_8_l_128_4_eth1], "ViT-Large - Minibatch 128 - Tau 4", "Ethernet", color='blue', plot_ideal=False, asynch=True)
plot_speedup([ddp_1_l_128_4_eth1, ddp_2_l_128_4_ib0, ddp_4_l_128_4_ib0, ddp_8_l_128_4_ib0], "ViT-Large - Minibatch 128 - Tau 4", "OPX", color='red', plot_ideal=True, asynch=True)
plt.tight_layout()

# %%
plt.figure(figsize=(10,6))
plot_speedup([ddp_1_l_128_8_eth1, ddp_2_l_128_8_eth1, ddp_4_l_128_8_eth1, ddp_8_l_128_8_eth1], "ViT-Large - Minibatch 128 - Tau 8", "Ethernet", color='blue', plot_ideal=False, asynch=True)
plot_speedup([ddp_1_l_128_8_eth1, ddp_2_l_128_8_ib0, ddp_4_l_128_8_ib0, ddp_8_l_128_8_ib0], "ViT-Large - Minibatch 128 - Tau 8", "OPX", color='red', plot_ideal=True, asynch=True)
plt.tight_layout()

# %%
ddp_1_l_256_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_1_minibatch_256_tau_2_vit-large-patch16-224-in21k_model_eth1.csv")
ddp_2_l_256_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_256_tau_2_vit-large-patch16-224-in21k_model_eth1.csv")
ddp_4_l_256_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_256_tau_2_vit-large-patch16-224-in21k_model_eth1.csv")
ddp_8_l_256_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_256_tau_2_vit-large-patch16-224-in21k_model_eth1.csv")

ddp_2_l_256_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_256_tau_2_vit-large-patch16-224-in21k_model_ib0.csv")
ddp_4_l_256_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_256_tau_2_vit-large-patch16-224-in21k_model_ib0.csv")
ddp_8_l_256_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_256_tau_2_vit-large-patch16-224-in21k_model_ib0.csv")

ddp_1_l_256_2_eth1 = ddp_1_l_256_2_eth1[ddp_1_l_256_2_eth1['phase'] == 'train']
ddp_2_l_256_2_eth1 = ddp_2_l_256_2_eth1[ddp_2_l_256_2_eth1['phase'] == 'train']
ddp_4_l_256_2_eth1 = ddp_4_l_256_2_eth1[ddp_4_l_256_2_eth1['phase'] == 'train']
ddp_8_l_256_2_eth1 = ddp_8_l_256_2_eth1[ddp_8_l_256_2_eth1['phase'] == 'train']

ddp_2_l_256_2_ib0 = ddp_2_l_256_2_ib0[ddp_2_l_256_2_ib0['phase'] == 'train']
ddp_4_l_256_2_ib0 = ddp_4_l_256_2_ib0[ddp_4_l_256_2_ib0['phase'] == 'train']
ddp_8_l_256_2_ib0 = ddp_8_l_256_2_ib0[ddp_8_l_256_2_ib0['phase'] == 'train']
# ------------------------------- TAU 4 ---------------------------------------------------
ddp_1_l_256_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_1_minibatch_256_tau_4_vit-large-patch16-224-in21k_model_eth1.csv")
ddp_2_l_256_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_256_tau_4_vit-large-patch16-224-in21k_model_eth1.csv")
ddp_4_l_256_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_256_tau_4_vit-large-patch16-224-in21k_model_eth1.csv")
ddp_8_l_256_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_256_tau_4_vit-large-patch16-224-in21k_model_eth1.csv")

ddp_2_l_256_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_256_tau_4_vit-large-patch16-224-in21k_model_ib0.csv")
ddp_4_l_256_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_256_tau_4_vit-large-patch16-224-in21k_model_ib0.csv")
ddp_8_l_256_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_256_tau_4_vit-large-patch16-224-in21k_model_ib0.csv")

ddp_1_l_256_4_eth1 = ddp_1_l_256_4_eth1[ddp_1_l_256_4_eth1['phase'] == 'train']
ddp_2_l_256_4_eth1 = ddp_2_l_256_4_eth1[ddp_2_l_256_4_eth1['phase'] == 'train']
ddp_4_l_256_4_eth1 = ddp_4_l_256_4_eth1[ddp_4_l_256_4_eth1['phase'] == 'train']
ddp_8_l_256_4_eth1 = ddp_8_l_256_4_eth1[ddp_8_l_256_4_eth1['phase'] == 'train']

ddp_2_l_256_4_ib0 = ddp_2_l_256_4_ib0[ddp_2_l_256_4_ib0['phase'] == 'train']
ddp_4_l_256_4_ib0 = ddp_4_l_256_4_ib0[ddp_4_l_256_4_ib0['phase'] == 'train']
ddp_8_l_256_4_ib0 = ddp_8_l_256_4_ib0[ddp_8_l_256_4_ib0['phase'] == 'train']

# ----------------------------------- TAU 8 ----------------------------------------------------
ddp_1_l_256_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_1_minibatch_256_tau_8_vit-large-patch16-224-in21k_model_eth1.csv")
ddp_2_l_256_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_256_tau_8_vit-large-patch16-224-in21k_model_eth1.csv")
ddp_4_l_256_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_256_tau_8_vit-large-patch16-224-in21k_model_eth1.csv")
ddp_8_l_256_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_256_tau_8_vit-large-patch16-224-in21k_model_eth1.csv")

ddp_2_l_256_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_256_tau_8_vit-large-patch16-224-in21k_model_ib0.csv")
ddp_4_l_256_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_256_tau_8_vit-large-patch16-224-in21k_model_ib0.csv")
ddp_8_l_256_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_256_tau_8_vit-large-patch16-224-in21k_model_ib0.csv")

ddp_1_l_256_8_eth1 = ddp_1_l_256_8_eth1[ddp_1_l_256_8_eth1['phase'] == 'train']
ddp_2_l_256_8_eth1 = ddp_2_l_256_8_eth1[ddp_2_l_256_8_eth1['phase'] == 'train']
ddp_4_l_256_8_eth1 = ddp_4_l_256_8_eth1[ddp_4_l_256_8_eth1['phase'] == 'train']
ddp_8_l_256_8_eth1 = ddp_8_l_256_8_eth1[ddp_8_l_256_8_eth1['phase'] == 'train']

ddp_2_l_256_8_ib0 = ddp_2_l_256_8_ib0[ddp_2_l_256_8_ib0['phase'] == 'train']
ddp_4_l_256_8_ib0 = ddp_4_l_256_8_ib0[ddp_4_l_256_8_ib0['phase'] == 'train']
ddp_8_l_256_8_ib0 = ddp_8_l_256_8_ib0[ddp_8_l_256_8_ib0['phase'] == 'train']

# %%
plt.figure(figsize=(10,6))
plot_speedup([ddp_1_l_256_2_eth1, ddp_2_l_256_2_ib0, ddp_4_l_256_2_eth1, ddp_8_l_256_2_eth1], "ViT-Large - Minibatch 256 - Tau 2", "Ethernet", color='blue', plot_ideal=False, asynch=True)
plot_speedup([ddp_1_l_256_2_eth1, ddp_2_l_256_2_eth1, ddp_4_l_256_2_ib0, ddp_8_l_256_2_ib0], "ViT-Large - Minibatch 256 - Tau 2", "OPX", color='red', plot_ideal=True, asynch=True)
plt.tight_layout()

# %%
plt.figure(figsize=(10,6))
plot_speedup([ddp_1_l_256_4_eth1, ddp_2_l_256_4_eth1, ddp_4_l_256_4_eth1, ddp_8_l_256_4_eth1], "ViT-Large - Minibatch 256 - Tau 4", "Ethernet", color='blue', plot_ideal=False, asynch=True)
plot_speedup([ddp_1_l_256_4_eth1, ddp_2_l_256_4_ib0, ddp_4_l_256_4_ib0, ddp_8_l_256_4_ib0], "ViT-Large - Minibatch 256 - Tau 4", "OPX", color='red', plot_ideal=True, asynch=True)
plt.tight_layout()

# %%
plt.figure(figsize=(10,6))
plot_speedup([ddp_1_l_256_8_eth1, ddp_2_l_256_8_eth1, ddp_4_l_256_8_eth1, ddp_8_l_256_8_eth1], "ViT-Large - Minibatch 256 - Tau 8", "Ethernet", color='blue', plot_ideal=False, asynch=True)
plot_speedup([ddp_1_l_256_8_eth1, ddp_2_l_256_8_ib0, ddp_4_l_256_8_ib0, ddp_8_l_256_8_ib0], "ViT-Large - Minibatch 256 - Tau 8", "OPX", color='red', plot_ideal=True, asynch=True)
plt.tight_layout()

# %% [markdown]
# ## Huge

# %%
ddp_1_h_64_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_1_minibatch_64_tau_2_vit-huge-patch14-224-in21k_model_eth1.csv")
ddp_2_h_64_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_64_tau_2_vit-huge-patch14-224-in21k_model_eth1.csv")
ddp_4_h_64_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_64_tau_2_vit-huge-patch14-224-in21k_model_eth1.csv")
ddp_8_h_64_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_64_tau_2_vit-huge-patch14-224-in21k_model_eth1.csv")

ddp_2_h_64_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_64_tau_2_vit-huge-patch14-224-in21k_model_ib0.csv")
ddp_4_h_64_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_64_tau_2_vit-huge-patch14-224-in21k_model_ib0.csv")
ddp_8_h_64_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_64_tau_2_vit-huge-patch14-224-in21k_model_ib0.csv")

ddp_1_h_64_2_eth1 = ddp_1_h_64_2_eth1[ddp_1_h_64_2_eth1['phase'] == 'train']
ddp_2_h_64_2_eth1 = ddp_2_h_64_2_eth1[ddp_2_h_64_2_eth1['phase'] == 'train']
ddp_4_h_64_2_eth1 = ddp_4_h_64_2_eth1[ddp_4_h_64_2_eth1['phase'] == 'train']
ddp_8_h_64_2_eth1 = ddp_8_h_64_2_eth1[ddp_8_h_64_2_eth1['phase'] == 'train']

ddp_2_h_64_2_ib0 = ddp_2_h_64_2_ib0[ddp_2_h_64_2_ib0['phase'] == 'train']
ddp_4_h_64_2_ib0 = ddp_4_h_64_2_ib0[ddp_4_h_64_2_ib0['phase'] == 'train']
ddp_8_h_64_2_ib0 = ddp_8_h_64_2_ib0[ddp_8_h_64_2_ib0['phase'] == 'train']

# ------------------------------- TAU 4 ---------------------------------------------------
ddp_1_h_64_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_1_minibatch_64_tau_4_vit-huge-patch14-224-in21k_model_eth1.csv")
ddp_2_h_64_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_64_tau_4_vit-huge-patch14-224-in21k_model_eth1.csv")
ddp_4_h_64_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_64_tau_4_vit-huge-patch14-224-in21k_model_eth1.csv")
ddp_8_h_64_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_64_tau_4_vit-huge-patch14-224-in21k_model_eth1.csv")

ddp_2_h_64_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_64_tau_4_vit-huge-patch14-224-in21k_model_ib0.csv")
ddp_4_h_64_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_64_tau_4_vit-huge-patch14-224-in21k_model_ib0.csv")
ddp_8_h_64_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_64_tau_4_vit-huge-patch14-224-in21k_model_ib0.csv")

ddp_1_h_64_4_eth1 = ddp_1_h_64_4_eth1[ddp_1_h_64_4_eth1['phase'] == 'train']
ddp_2_h_64_4_eth1 = ddp_2_h_64_4_eth1[ddp_2_h_64_4_eth1['phase'] == 'train']
ddp_4_h_64_4_eth1 = ddp_4_h_64_4_eth1[ddp_4_h_64_4_eth1['phase'] == 'train']
ddp_8_h_64_4_eth1 = ddp_8_h_64_4_eth1[ddp_8_h_64_4_eth1['phase'] == 'train']

ddp_2_h_64_4_ib0 = ddp_2_h_64_4_ib0[ddp_2_h_64_4_ib0['phase'] == 'train']
ddp_4_h_64_4_ib0 = ddp_4_h_64_4_ib0[ddp_4_h_64_4_ib0['phase'] == 'train']
ddp_8_h_64_4_ib0 = ddp_8_h_64_4_ib0[ddp_8_h_64_4_ib0['phase'] == 'train']

# ----------------------------------- TAU 8 ----------------------------------------------------
ddp_1_h_64_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_1_minibatch_64_tau_8_vit-huge-patch14-224-in21k_model_eth1.csv")
ddp_2_h_64_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_64_tau_8_vit-huge-patch14-224-in21k_model_eth1.csv")
ddp_4_h_64_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_64_tau_8_vit-huge-patch14-224-in21k_model_eth1.csv")
ddp_8_h_64_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_64_tau_8_vit-huge-patch14-224-in21k_model_eth1.csv")

ddp_2_h_64_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_64_tau_8_vit-huge-patch14-224-in21k_model_ib0.csv")
ddp_4_h_64_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_64_tau_8_vit-huge-patch14-224-in21k_model_ib0.csv")
ddp_8_h_64_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_64_tau_8_vit-huge-patch14-224-in21k_model_ib0.csv")

ddp_1_h_64_8_eth1 = ddp_1_h_64_8_eth1[ddp_1_h_64_8_eth1['phase'] == 'train']
ddp_2_h_64_8_eth1 = ddp_2_h_64_8_eth1[ddp_2_h_64_8_eth1['phase'] == 'train']
ddp_4_h_64_8_eth1 = ddp_4_h_64_8_eth1[ddp_4_h_64_8_eth1['phase'] == 'train']
ddp_8_h_64_8_eth1 = ddp_8_h_64_8_eth1[ddp_8_h_64_8_eth1['phase'] == 'train']

ddp_2_h_64_8_ib0 = ddp_2_h_64_8_ib0[ddp_2_h_64_8_ib0['phase'] == 'train']
ddp_4_h_64_8_ib0 = ddp_4_h_64_8_ib0[ddp_4_h_64_8_ib0['phase'] == 'train']
ddp_8_h_64_8_ib0 = ddp_8_h_64_8_ib0[ddp_8_h_64_8_ib0['phase'] == 'train']

# %%
plt.figure(figsize=(10,6))
plot_speedup([ddp_1_h_64_2_eth1, ddp_2_h_64_2_eth1, ddp_4_h_64_2_eth1, ddp_8_h_64_2_eth1], "ViT-Huge - Minibatch 64 - Tau 2", "Ethernet", color='blue', plot_ideal=False, asynch=True)
plot_speedup([ddp_1_h_64_2_eth1, ddp_2_h_64_2_ib0, ddp_4_h_64_2_ib0, ddp_8_h_64_2_ib0], "ViT-Huge - Minibatch 64 - Tau 2", "OPX", color='red', plot_ideal=True, asynch=True)
plt.tight_layout()

# %%
plt.figure(figsize=(10,6))
plot_speedup([ddp_1_h_64_4_eth1, ddp_2_h_64_4_eth1, ddp_4_h_64_4_eth1, ddp_8_h_64_4_eth1], "ViT-Huge - Minibatch 64 - Tau 4", "Ethernet", color='blue', plot_ideal=False, asynch=True)
plot_speedup([ddp_1_h_64_4_eth1, ddp_2_h_64_4_ib0, ddp_4_h_64_4_ib0, ddp_8_h_64_4_ib0], "ViT-Huge - Minibatch 64 - Tau 4", "OPX", color='red', plot_ideal=True, asynch=True)
plt.tight_layout()

# %%
plt.figure(figsize=(10,6))
plot_speedup([ddp_1_h_64_8_eth1, ddp_2_h_64_8_eth1, ddp_4_h_64_8_eth1, ddp_8_h_64_8_eth1], "ViT-Huge - Minibatch 64 - Tau 8", "Ethernet", color='blue', plot_ideal=False, asynch=True)
plot_speedup([ddp_1_h_64_8_eth1, ddp_2_h_64_8_ib0, ddp_4_h_64_8_ib0, ddp_8_h_64_8_ib0], "ViT-Huge - Minibatch 64 - Tau 8", "OPX", color='red', plot_ideal=True, asynch=True)
plt.tight_layout()

# %%
ddp_1_h_128_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_1_minibatch_128_tau_2_vit-huge-patch14-224-in21k_model_eth1.csv")
ddp_2_h_128_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_128_tau_2_vit-huge-patch14-224-in21k_model_eth1.csv")
ddp_4_h_128_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_128_tau_2_vit-huge-patch14-224-in21k_model_eth1.csv")
ddp_8_h_128_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_128_tau_2_vit-huge-patch14-224-in21k_model_eth1.csv")

ddp_2_h_128_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_128_tau_2_vit-huge-patch14-224-in21k_model_ib0.csv")
ddp_4_h_128_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_128_tau_2_vit-huge-patch14-224-in21k_model_ib0.csv")
ddp_8_h_128_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_128_tau_2_vit-huge-patch14-224-in21k_model_ib0.csv")

ddp_1_h_128_2_eth1 = ddp_1_h_128_2_eth1[ddp_1_h_128_2_eth1['phase'] == 'train']
ddp_2_h_128_2_eth1 = ddp_2_h_128_2_eth1[ddp_2_h_128_2_eth1['phase'] == 'train']
ddp_4_h_128_2_eth1 = ddp_4_h_128_2_eth1[ddp_4_h_128_2_eth1['phase'] == 'train']
ddp_8_h_128_2_eth1 = ddp_8_h_128_2_eth1[ddp_8_h_128_2_eth1['phase'] == 'train']

ddp_2_h_128_2_ib0 = ddp_2_h_128_2_ib0[ddp_2_h_128_2_ib0['phase'] == 'train']
ddp_4_h_128_2_ib0 = ddp_4_h_128_2_ib0[ddp_4_h_128_2_ib0['phase'] == 'train']
ddp_8_h_128_2_ib0 = ddp_8_h_128_2_ib0[ddp_8_h_128_2_ib0['phase'] == 'train']

# ------------------------------- TAU 4 ---------------------------------------------------
ddp_1_h_128_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_1_minibatch_128_tau_4_vit-huge-patch14-224-in21k_model_eth1.csv")
ddp_2_h_128_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_128_tau_4_vit-huge-patch14-224-in21k_model_eth1.csv")
ddp_4_h_128_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_128_tau_4_vit-huge-patch14-224-in21k_model_eth1.csv")
ddp_8_h_128_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_128_tau_4_vit-huge-patch14-224-in21k_model_eth1.csv")

ddp_2_h_128_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_128_tau_4_vit-huge-patch14-224-in21k_model_ib0.csv")
ddp_4_h_128_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_128_tau_4_vit-huge-patch14-224-in21k_model_ib0.csv")
ddp_8_h_128_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_128_tau_4_vit-huge-patch14-224-in21k_model_ib0.csv")

ddp_1_h_128_4_eth1 = ddp_1_h_128_4_eth1[ddp_1_h_128_4_eth1['phase'] == 'train']
ddp_2_h_128_4_eth1 = ddp_2_h_128_4_eth1[ddp_2_h_128_4_eth1['phase'] == 'train']
ddp_4_h_128_4_eth1 = ddp_4_h_128_4_eth1[ddp_4_h_128_4_eth1['phase'] == 'train']
ddp_8_h_128_4_eth1 = ddp_8_h_128_4_eth1[ddp_8_h_128_4_eth1['phase'] == 'train']

ddp_2_h_128_4_ib0 = ddp_2_h_128_4_ib0[ddp_2_h_128_4_ib0['phase'] == 'train']
ddp_4_h_128_4_ib0 = ddp_4_h_128_4_ib0[ddp_4_h_128_4_ib0['phase'] == 'train']
ddp_8_h_128_4_ib0 = ddp_8_h_128_4_ib0[ddp_8_h_128_4_ib0['phase'] == 'train']

# ----------------------------------- TAU 8 ----------------------------------------------------
ddp_1_h_128_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_1_minibatch_128_tau_8_vit-huge-patch14-224-in21k_model_eth1.csv")
ddp_2_h_128_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_128_tau_8_vit-huge-patch14-224-in21k_model_eth1.csv")
ddp_4_h_128_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_128_tau_8_vit-huge-patch14-224-in21k_model_eth1.csv")
ddp_8_h_128_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_128_tau_8_vit-huge-patch14-224-in21k_model_eth1.csv")

ddp_2_h_128_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_128_tau_8_vit-huge-patch14-224-in21k_model_ib0.csv")
ddp_4_h_128_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_128_tau_8_vit-huge-patch14-224-in21k_model_ib0.csv")
ddp_8_h_128_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_128_tau_8_vit-huge-patch14-224-in21k_model_ib0.csv")

ddp_1_h_128_8_eth1 = ddp_1_h_128_8_eth1[ddp_1_h_128_8_eth1['phase'] == 'train']
ddp_2_h_128_8_eth1 = ddp_2_h_128_8_eth1[ddp_2_h_128_8_eth1['phase'] == 'train']
ddp_4_h_128_8_eth1 = ddp_4_h_128_8_eth1[ddp_4_h_128_8_eth1['phase'] == 'train']
ddp_8_h_128_8_eth1 = ddp_8_h_128_8_eth1[ddp_8_h_128_8_eth1['phase'] == 'train']

ddp_2_h_128_8_ib0 = ddp_2_h_128_8_ib0[ddp_2_h_128_8_ib0['phase'] == 'train']
ddp_4_h_128_8_ib0 = ddp_4_h_128_8_ib0[ddp_4_h_128_8_ib0['phase'] == 'train']
ddp_8_h_128_8_ib0 = ddp_8_h_128_8_ib0[ddp_8_h_128_8_ib0['phase'] == 'train']

# %%
plt.figure(figsize=(10,6))
plot_speedup([ddp_1_h_128_2_eth1, ddp_2_h_128_2_eth1, ddp_4_h_128_2_eth1, ddp_8_h_128_2_eth1], "ViT-Huge - Minibatch 128 - Tau 2", "Ethernet", color='blue', plot_ideal=False, asynch=True)
plot_speedup([ddp_1_h_128_2_eth1, ddp_2_h_128_2_ib0, ddp_4_h_128_2_ib0, ddp_8_h_128_2_ib0], "ViT-Huge - Minibatch 128 - Tau 2", "OPX", color='red', plot_ideal=True, asynch=True)
plt.tight_layout()

# %%
plt.figure(figsize=(10,6))
plot_speedup([ddp_1_h_128_4_eth1, ddp_2_h_128_4_eth1, ddp_4_h_128_4_eth1, ddp_8_h_128_4_eth1], "ViT-Huge - Minibatch 128 - Tau 4", "Ethernet", color='blue', plot_ideal=False, asynch=True)
plot_speedup([ddp_1_h_128_4_eth1, ddp_2_h_128_4_ib0, ddp_4_h_128_4_ib0, ddp_8_h_128_4_ib0], "ViT-Huge - Minibatch 128 - Tau 4", "OPX", color='red', plot_ideal=True, asynch=True)
plt.tight_layout()

# %%
plt.figure(figsize=(10,6))
plot_speedup([ddp_1_h_128_8_eth1, ddp_2_h_128_8_eth1, ddp_4_h_128_8_eth1, ddp_8_h_128_8_eth1], "ViT-Huge - Minibatch 128 - Tau 8", "Ethernet", color='blue', plot_ideal=False, asynch=True)
plot_speedup([ddp_1_h_128_8_eth1, ddp_2_h_128_8_ib0, ddp_4_h_128_8_ib0, ddp_8_h_128_8_ib0], "ViT-Huge - Minibatch 128 - Tau 8", "OPX", color='red', plot_ideal=True, asynch=True)
plt.tight_layout()

# %%
# ddp_1_h_256_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_1_minibatch_256_tau_2_vit-huge-patch14-224-in21k_model_eth1.csv")
ddp_2_h_256_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_256_tau_2_vit-huge-patch14-224-in21k_model_eth1.csv")
ddp_4_h_256_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_256_tau_2_vit-huge-patch14-224-in21k_model_eth1.csv")
ddp_8_h_256_2_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_256_tau_2_vit-huge-patch14-224-in21k_model_eth1.csv")

ddp_2_h_256_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_256_tau_2_vit-huge-patch14-224-in21k_model_ib0.csv")
ddp_4_h_256_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_256_tau_2_vit-huge-patch14-224-in21k_model_ib0.csv")
ddp_8_h_256_2_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_256_tau_2_vit-huge-patch14-224-in21k_model_ib0.csv")

# ddp_1_h_256_2_eth1 = ddp_1_h_256_2_eth1[ddp_1_h_256_2_eth1['phase'] == 'train']
ddp_2_h_256_2_eth1 = ddp_2_h_256_2_eth1[ddp_2_h_256_2_eth1['phase'] == 'train']
ddp_4_h_256_2_eth1 = ddp_4_h_256_2_eth1[ddp_4_h_256_2_eth1['phase'] == 'train']
ddp_8_h_256_2_eth1 = ddp_8_h_256_2_eth1[ddp_8_h_256_2_eth1['phase'] == 'train']

ddp_2_h_256_2_ib0 = ddp_2_h_256_2_ib0[ddp_2_h_256_2_ib0['phase'] == 'train']
ddp_4_h_256_2_ib0 = ddp_4_h_256_2_ib0[ddp_4_h_256_2_ib0['phase'] == 'train']
ddp_8_h_256_2_ib0 = ddp_8_h_256_2_ib0[ddp_8_h_256_2_ib0['phase'] == 'train']

# ------------------------------- TAU 4 ---------------------------------------------------
# ddp_1_h_256_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_1_minibatch_256_tau_4_vit-huge-patch14-224-in21k_model_eth1.csv")
ddp_2_h_256_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_256_tau_4_vit-huge-patch14-224-in21k_model_eth1.csv")
ddp_4_h_256_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_256_tau_4_vit-huge-patch14-224-in21k_model_eth1.csv")
ddp_8_h_256_4_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_256_tau_4_vit-huge-patch14-224-in21k_model_eth1.csv")

ddp_2_h_256_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_256_tau_4_vit-huge-patch14-224-in21k_model_ib0.csv")
ddp_4_h_256_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_256_tau_4_vit-huge-patch14-224-in21k_model_ib0.csv")
ddp_8_h_256_4_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_256_tau_4_vit-huge-patch14-224-in21k_model_ib0.csv")

# ddp_1_h_256_4_eth1 = ddp_1_h_256_4_eth1[ddp_1_h_256_4_eth1['phase'] == 'train']
ddp_2_h_256_4_eth1 = ddp_2_h_256_4_eth1[ddp_2_h_256_4_eth1['phase'] == 'train']
ddp_4_h_256_4_eth1 = ddp_4_h_256_4_eth1[ddp_4_h_256_4_eth1['phase'] == 'train']
ddp_8_h_256_4_eth1 = ddp_8_h_256_4_eth1[ddp_8_h_256_4_eth1['phase'] == 'train']

ddp_2_h_256_4_ib0 = ddp_2_h_256_4_ib0[ddp_2_h_256_4_ib0['phase'] == 'train']
ddp_4_h_256_4_ib0 = ddp_4_h_256_4_ib0[ddp_4_h_256_4_ib0['phase'] == 'train']
ddp_8_h_256_4_ib0 = ddp_8_h_256_4_ib0[ddp_8_h_256_4_ib0['phase'] == 'train']

# ----------------------------------- TAU 8 ----------------------------------------------------
# ddp_1_h_256_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_1_minibatch_256_tau_8_vit-huge-patch14-224-in21k_model_eth1.csv")
ddp_2_h_256_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_256_tau_8_vit-huge-patch14-224-in21k_model_eth1.csv")
ddp_4_h_256_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_256_tau_8_vit-huge-patch14-224-in21k_model_eth1.csv")
ddp_8_h_256_8_eth1 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_256_tau_8_vit-huge-patch14-224-in21k_model_eth1.csv")

ddp_2_h_256_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_256_tau_8_vit-huge-patch14-224-in21k_model_ib0.csv")
ddp_4_h_256_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_256_tau_8_vit-huge-patch14-224-in21k_model_ib0.csv")
ddp_8_h_256_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_256_tau_8_vit-huge-patch14-224-in21k_model_ib0.csv")

# ddp_1_h_256_8_eth1 = ddp_1_h_256_8_eth1[ddp_1_h_256_8_eth1['phase'] == 'train']
ddp_2_h_256_8_eth1 = ddp_2_h_256_8_eth1[ddp_2_h_256_8_eth1['phase'] == 'train']
ddp_4_h_256_8_eth1 = ddp_4_h_256_8_eth1[ddp_4_h_256_8_eth1['phase'] == 'train']
ddp_8_h_256_8_eth1 = ddp_8_h_256_8_eth1[ddp_8_h_256_8_eth1['phase'] == 'train']

ddp_2_h_256_8_ib0 = ddp_2_h_256_8_ib0[ddp_2_h_256_8_ib0['phase'] == 'train']
ddp_4_h_256_8_ib0 = ddp_4_h_256_8_ib0[ddp_4_h_256_8_ib0['phase'] == 'train']
ddp_8_h_256_8_ib0 = ddp_8_h_256_8_ib0[ddp_8_h_256_8_ib0['phase'] == 'train']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[127], line 46
#      44 ddp_2_h_256_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_2_minibatch_256_tau_8_vit-huge-patch14-224-in21k_model_ib0.csv")
#      45 ddp_4_h_256_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_4_minibatch_256_tau_8_vit-huge-patch14-224-in21k_model_ib0.csv")
# ---> 46 ddp_8_h_256_8_ib0 = pd.read_csv("../log/asynch_ddp/rank_0_asynch_ddp_8_minibatch_256_tau_8_vit-huge-patch14-224-in21k_model_ib0.csv")
#      48 # ddp_1_h_256_8_eth1 = ddp_1_h_256_8_eth1[ddp_1_h_256_8_eth1['phase'] == 'train']
#      49 ddp_2_h_256_8_eth1 = ddp_2_h_256_8_eth1[ddp_2_h_256_8_eth1['phase'] == 'train']
#
# ...

# %%
plt.figure(figsize=(10,6))
plot_speedup([ddp_2_h_256_2_eth1, ddp_4_h_256_2_eth1, ddp_8_h_256_2_eth1], "ViT-Huge - Minibatch 256 - Tau 2", "Ethernet", color='blue', plot_ideal=False, asynch=True)
plot_speedup([ddp_2_h_256_2_ib0, ddp_4_h_256_2_ib0, ddp_8_h_256_2_ib0], "ViT-Huge - Minibatch 256 - Tau 2", "OPX", color='red', plot_ideal=True, asynch=True)
plt.tight_layout()

# %%
plt.figure(figsize=(10,6))
plot_speedup([ddp_2_h_256_4_eth1, ddp_4_h_256_4_eth1, ddp_8_h_256_4_eth1], "ViT-Huge - Minibatch 256 - Tau 4", "Ethernet", color='blue', plot_ideal=False, asynch=True)
plot_speedup([ddp_2_h_256_4_ib0, ddp_4_h_256_4_ib0, ddp_8_h_256_4_ib0], "ViT-Huge - Minibatch 256 - Tau 4", "OPX", color='red', plot_ideal=True, asynch=True)
plt.tight_layout()

# %%
plt.figure(figsize=(10,6))
plot_speedup([ddp_2_h_256_8_eth1, ddp_4_h_256_8_eth1, ddp_8_h_256_8_eth1], "ViT-Huge - Minibatch 256 - Tau 8", "Ethernet", color='blue', plot_ideal=False, asynch=True)
plot_speedup([ddp_2_h_256_8_ib0, ddp_4_h_256_8_ib0, ddp_8_h_256_8_ib0], "ViT-Huge - Minibatch 256 - Tau 8", "OPX", color='red', plot_ideal=True, asynch=True)
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[130], line 3
#       1 plt.figure(figsize=(10,6))
#       2 plot_speedup([ddp_2_h_256_8_eth1, ddp_4_h_256_8_eth1, ddp_8_h_256_8_eth1], "ViT-Huge - Minibatch 256 - Tau 8", "Ethernet", color='blue', plot_ideal=False, asynch=True)
# ----> 3 plot_speedup([ddp_2_h_256_8_ib0, ddp_4_h_256_8_ib0, ddp_8_h_256_8_ib0], "ViT-Huge - Minibatch 256 - Tau 8", "OPX", color='red', plot_ideal=True, asynch=True)
#       4 plt.tight_layout()
#
# NameError: name 'ddp_8_h_256_8_ib0' is not defined

# %% [markdown]
# ## Synch Time

# %%
def plot_synch_avg_comparison_general(eth_data: dict, opx_data: dict, model_name='Base'):
    """
    Plots a grouped bar chart of synch_avg_time (excluding 0) for various worker counts,
    comparing Ethernet vs OPX for a given ViT model.

    Parameters:
    - eth_data: Dict[int, pd.DataFrame], mapping worker count to Ethernet DataFrame
    - opx_data: Dict[int, pd.DataFrame], mapping worker count to OPX DataFrame
    - model_name: 'Base', 'Large', or 'Huge'
    """

    def avg_synch(df):
        return df.loc[df['synch_avg_time'] != 0, 'synch_avg_time'].mean()

    # Sorted list of common worker counts
    worker_counts = sorted(set(eth_data.keys()).intersection(opx_data.keys()))

    ethernet_vals = [avg_synch(eth_data[w]) for w in worker_counts]
    opx_vals = [avg_synch(opx_data[w]) for w in worker_counts]
    labels = [f'{w} Workers' for w in worker_counts]
    x = np.arange(len(worker_counts))
    bar_width = 0.35

    # Plot
    fig, ax = plt.subplots(figsize=(10, 6))
    ax.bar(x - bar_width/2, ethernet_vals, width=bar_width, label='Ethernet', color='#1f77b4')
    ax.bar(x + bar_width/2, opx_vals, width=bar_width, label='OPX', color='#d62728')

    # Annotate bars
    for i in range(len(x)):
        ax.text(x[i] - bar_width/2, ethernet_vals[i], f"{ethernet_vals[i]:.2f}", ha='center', va='bottom')
        ax.text(x[i] + bar_width/2, opx_vals[i], f"{opx_vals[i]:.2f}", ha='center', va='bottom')

    # Style
    ax.set_title(f'ViT-{model_name} - Parameters Averaging Time')
    ax.set_ylabel('Time (s)')
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax.legend()
    ax.grid(axis='y', linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()

# %%
# # ViT-Base
# eth_data_base = {
#     2: ddp_2_h_64_8_eth1,
#     4: ddp_4_h_64_8_eth1,
#     8: ddp_8_h_64_8_eth1,
# }
# opx_data_base = {
#     2: ddp_2_h_64_8_ib0,
#     4: ddp_4_h_64_8_ib0,
#     8: ddp_8_h_64_8_ib0,
# }
# plot_synch_avg_comparison_general(eth_data_base, opx_data_base, model_name='Huge')
